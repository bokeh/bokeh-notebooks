# %% [raw]
# This IPython Notebook contains simple examples of the line function.
#
# To clear all previously rendered cell outputs, select from the menu:
#
#     Cell -> All Output -> Clear

# %%
import numpy as np
from scipy.integrate import odeint

# %%
from bokeh.plotting import figure, output_notebook, show

# %%
sigma = 10
rho = 28
beta = 8.0/3
theta = 3 * np.pi / 4

# %%
def lorenz(xyz, t):
    x, y, z = xyz
    x_dot = sigma * (y - x)
    y_dot = x * rho - x * z - y
    z_dot = x * y - beta* z
    return [x_dot, y_dot, z_dot]

# %%
initial = (-10, -7, 35)
t = np.arange(0, 100, 0.001)

# %%
solution = odeint(lorenz, initial, t)

# %%
x = solution[:, 0]
y = solution[:, 1]
z = solution[:, 2]
xprime = np.cos(theta) * x - np.sin(theta) * y

# %%
colors = ["#C6DBEF", "#9ECAE1", "#6BAED6", "#4292C6", "#2171B5", "#08519C", "#08306B",]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b651e690-6921-4559-a934-090492d7120d">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(title="lorenz example")
p.multi_line(np.array_split(xprime, 7), np.array_split(z, 7),
           line_color=colors, line_alpha=0.8, line_width=1.5)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="8b13b595-be22-4f05-9a29-587dc8a5c3df"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8b13b595-be22-4f05-9a29-587dc8a5c3df");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8b13b595-be22-4f05-9a29-587dc8a5c3df' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"53360088-36bf-461d-8892-646f66984981":{"roots":{"references":[{"attributes":{"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"},"ticker":{"id":"04fd6959-4608-47eb-b544-15865cc28150","type":"BasicTicker"}},"id":"909f992b-c452-44f1-bf85-eb118285b746","type":"Grid"},{"attributes":{"formatter":{"id":"850710a6-20b3-41b6-b502-d4f2efdff720","type":"BasicTickFormatter"},"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"},"ticker":{"id":"89c2ff71-3102-4fa2-aa78-9391e07f8647","type":"BasicTicker"}},"id":"fe73d6b2-c5a6-4532-9b67-dd96233de383","type":"LinearAxis"},{"attributes":{"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"}},"id":"27cb7cdd-01e5-4671-af09-deaf8e1f8f17","type":"PanTool"},{"attributes":{},"id":"0385f3cd-3fed-4448-80e8-75292f52b848","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.8},"line_color":{"field":"line_color"},"line_width":{"value":1.5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"e4c6d211-50aa-4a70-ac24-b5fe4f4b8d98","type":"MultiLine"},{"attributes":{"callback":null},"id":"f9d090fd-92ca-4b50-8840-4312de1e1781","type":"DataRange1d"},{"attributes":{"callback":null},"id":"e6485e31-58ea-4295-aa75-143eb9246304","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0aa070d5-8b94-4754-9816-a6bc7569fb79","type":"BoxAnnotation"},{"attributes":{},"id":"89c2ff71-3102-4fa2-aa78-9391e07f8647","type":"BasicTicker"},{"attributes":{"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"}},"id":"464263c3-7bc4-44d0-b45b-5f03be3a3113","type":"HelpTool"},{"attributes":{},"id":"850710a6-20b3-41b6-b502-d4f2efdff720","type":"BasicTickFormatter"},{"attributes":{},"id":"7a3c68b2-688b-48dd-89ba-4b2ac34ea11c","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"27cb7cdd-01e5-4671-af09-deaf8e1f8f17","type":"PanTool"},{"id":"470b6b01-1c43-4209-a737-642463ea88ee","type":"WheelZoomTool"},{"id":"293c85ce-ebdc-46b3-a17b-0349b4969a99","type":"BoxZoomTool"},{"id":"e2052e34-469f-4628-af96-c0225629906a","type":"SaveTool"},{"id":"55286abc-4a85-4a98-ae45-ca6ae50c75b4","type":"ResetTool"},{"id":"464263c3-7bc4-44d0-b45b-5f03be3a3113","type":"HelpTool"}]},"id":"9aec9f6e-ed5d-4ab1-9ae8-5ac134b9ff96","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":1.5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"e1961943-4d58-43f4-9689-f8f70650e3ec","type":"MultiLine"},{"attributes":{"overlay":{"id":"0aa070d5-8b94-4754-9816-a6bc7569fb79","type":"BoxAnnotation"},"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"}},"id":"293c85ce-ebdc-46b3-a17b-0349b4969a99","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"7a3c68b2-688b-48dd-89ba-4b2ac34ea11c","type":"BasicTickFormatter"},"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"},"ticker":{"id":"04fd6959-4608-47eb-b544-15865cc28150","type":"BasicTicker"}},"id":"39635551-6eee-4446-a8ab-88407a640b66","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"},"ticker":{"id":"89c2ff71-3102-4fa2-aa78-9391e07f8647","type":"BasicTicker"}},"id":"026537ec-738c-4129-8a3e-229946d2c609","type":"Grid"},{"attributes":{"plot":{"id":"6d89e331-5148-4cac-bccb-9b968b39c724","subtype":"Figure","type":"Plot"}},"id":"470b6b01-1c43-4209-a737-642463ea88ee","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"39635551-6eee-4446-a8ab-88407a640b66","type":"LinearAxis"}],"left":[{"id":"fe73d6b2-c5a6-4532-9b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>
