# %% [raw]
# This IPython Notebook contains simple examples of the line function.
#
# To clear all previously rendered cell outputs, select from the menu:
#
#     Cell -> All Output -> Clear

# %%
import numpy as np

# %%
from bokeh.plotting import figure, output_notebook, show

# %%
N = 4000

# %%
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

# %%
output_notebook()
# Out:
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev9.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev9.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-compiler-0.11.0dev9.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev9.min.css" type="text/css" />
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev9.min.css" type="text/css" />
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,tap,previewsave,box_select,poly_select,lasso_select"

p = figure(tools=TOOLS)
p.scatter(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# %%
show(p)
# Out:
#
#
#     <script type="text/javascript">
#         Bokeh.$(function() {
#         var docs_json = {"817fece5-b9b8-4ed8-8578-729f83e594ef": {"version": "0.11.0dev9", "roots": {"references": [{"type": "Circle", "id": "ffd98869-2c9f-49ba-81fb-340d01c841ee", "attributes": {"line_color": {"value": null}, "x": {"field": "x"}, "radius": {"field": "radius", "units": "data"}, "fill_color": {"field": "fill_color"}, "y": {"field": "y"}, "fill_alpha": {"value": 0.6}}}, {"type": "PolyAnnotation", "id": "3e58c085-a274-4341-8990-a713dc5ae8b4", "attributes": {"xs_units": "screen", "line_alpha": {"value": 1.0}, "level": "overlay", "line_color": {"value": "black"}, "fill_color": {"value": "lightgrey"}, "line_dash": [4, 4], "ys_units": "screen", "line_width": {"value": 2}, "fill_alpha": {"value": 0.5}, "plot": null}}, {"type": "BasicTickFormatter", "id": "1781e835-14b3-4e84-a338-c4b5147c50be", "attributes": {}}, {"type": "ResizeTool", "id": "4d160b30-0c73-4419-a231-d71aad40c12c", "attributes": {"plot": {"type": "Plot", "subtype": "Figure", "id": "c796e59d-b82e-48ac-b297-b6c8cf15dbf5"}}}, {"type": "PreviewSaveTool", "id": "df15bfe5-01ba-441d-9061-88bd9789c5ed", "attributes": {"plot": {"type": "Plot", "subtype": "Figure", "id": "c796e59d-b82e-48ac-b297-b6c8cf15dbf5"}}}, {"type": "GlyphRenderer", "id": "014cd03a-0cc0-40e8-ac43-304253b1a5f6", "attributes": {"selection_glyph": null, "nonselection_glyph": {"type": "Circle", "id": "4c5f4a6e-b812-4a93-a015-eec960d1d320"}, "hover_glyph": null, "glyph": {"type": "Circle", "id": "ffd98869-2c9f-49ba-81fb-340d01c841ee"}, "data_source": {"type":