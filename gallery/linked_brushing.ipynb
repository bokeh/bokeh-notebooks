# %%
import numpy as np

# %%
from bokeh.plotting import figure, gridplot, output_notebook, show
from bokeh.models import ColumnDataSource

# %%
output_notebook()
# Out:
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev9.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev9.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/dev/bokeh-compiler-0.11.0dev9.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/dev/bokeh-0.11.0dev9.min.css" type="text/css" />
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/dev/bokeh-widgets-0.11.0dev9.min.css" type="text/css" />
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
N = 300
x = np.linspace(0, 4*np.pi, N)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
source = ColumnDataSource(data=dict(x=x, y1=y1, y2=y2))

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

s1 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s1.scatter('x', 'y1', source=source)

# Linked brushing in Bokeh is expressed by sharing data sources between
# renderers. Note below that s2.scatter is called with the `source` 
# keyword argument, and supplied with the same data source from s1.scatter
s2 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s2.scatter('x', 'y2', source=source)

# %%
p = gridplot([[s1,s2]])
show(p)
# Out:
#
#
#     <script type="text/javascript">
#         Bokeh.$(function() {
#         var docs_json = {"eb9ecd67-3aac-418e-a287-a2702db36a1a": {"roots": {"references": [{"attributes": {"formatter": {"type": "BasicTickFormatter", "id": "3ee358fd-1a58-4a65-9dbf-1b6675da5bca"}, "plot": {"subtype": "Figure", "type": "Plot", "id": "4b34e8cd-51b5-47e6-9ffe-022f0f276a8e"}, "ticker": {"type": "BasicTicker", "id": "30515aab-af02-42f2-be47-2d5c9e30448b"}}, "type": "LinearAxis", "id": "a928638c-874b-4730-97a3-ac6bd820bfee"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "74b9fe2d-c55b-43b4-9d5e-fb397292f643"}}, "type": "PreviewSaveTool", "id": "029c7644-50e8-4def-82bc-fca009c1884b"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "13fa225f-2ec2-487e-a98c-d823eefd7067"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "4b34e8cd-51b5-47e6-9ffe-022f0f276a8e"}}, "type": "WheelZoomTool", "id": "b1625c42-1eb9-4fc9-a4bb-7f6afa44a468"}, {"attributes": {"formatter": {"type": "BasicTickFormatter", "id": "8b5b16b8-019a-4d2f-9dd0-ef74fe663d1a"}, "plot": {"subtype": "Figure", "type": "Plot", "id": "74b9fe2d-c55b-43b4-9d5e-fb397292f643"}, "ticker": {"type": "BasicTicker", "id": "9d3dd7bd-17fc-468d-9e26-b6b85c81a58f"}}, "type": "LinearAxis", "id": "adc95d51-c5ac-4bd6-8a9e-452d4a65d632"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "c1807ba5-ff2b-4ccd-bdab-70cd406e3f3e"}}, "type": "WheelZoomTool", "id": "eaf9e32d-554c-460a-9cfd-f2faa3687245"}, {"attributes": {"callback": null}, "type": "DataRange1d", "id": "77785140-17c2-4453-944a-df0682ae107a"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "74b9fe2d-c55b-43b4-9d5e-fb397292f643"}}, "type": "PanTool", "id": "50a1ac7f-92a7-41fc-846d-68d9a78333a3"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "4c761ed4-08c9-47a4-9946-2aedbf51fc5e"}, "ticker": {"type": "BasicTicker", "id": "acd12fe9-457b-49da-a0fb-c9051ac7db93"}}, "type": "Grid", "id": "d51d3b35-33cd-41ac-b086-21850ca10ee5"}, {"attributes": {"plot": {"subtype": "Figure", "type": "Plot", "id": "4c761ed4-08c9-47a4-9946-2aedbf51fc5e"}}, "type": "PanTool", "id": "e8f8323a-78d4-4bdb-88ee-ad45af056a22"}, {"attributes": {"overlay": {"type": "BoxAnnotation", "id": "71243571-ded2-4b97-affc-cfde4800cbdd"}, "plot": {"subtype": "Figure", "type": "Plot", "id": "74b9fe2d-c55b-43b4-9d5e-fb397292f643"}}, "type": "BoxZoomTool", "id": "8941420d-5b65-433e-9732-ef6246686ba3"}, {"attributes": {"x": {"field": "x"}, "fill_color": {"value": "#1f77b4"}, "line_color": {"value": "#1f77b4"}, "y": {"field": "y1"}}, "type": "Circle", "id": "f81b0f29-be36-454b-b1ed-cab45d2528b1"}, {"attributes": {"fill_color": {"value": "lightgrey"}, "line_dash": [4, 4], "line_color": {"value": "black"}, "plot": null, "xs_units": "screen", "ys_units": "screen", "fill_alpha": {"value": 0.5}, "line_width": {"value": 2}, "line_alpha": {"value": 1.0}, "level": "overlay"}, "type": "PolyAnnotation", "id": "0b25e0b2-d923-418e-b950-9cf8a8b99d31"}, {"attributes": {"render_mode": "css", "right_units": "screen", "bottom_units": "screen", "top_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "line_alpha": {"value": 1.0}, "fill_color": {"value": "lightgrey"}, "line_color": {"value": "black"}, "plot": null, "fill_alpha": {"value": 0.5}, "left_units": "screen", "level": "overlay"}, "type": "BoxAnnotation", "id": "fb2748eb-8e34-4fa9-9886-0d36fb414270"}, {"attributes": {"fill_color": {"value": "lightgrey"}, "line_dash": [4, 4], "line_color": {"value": "black"}, "plot": null, "xs_units": "screen", "ys_units": "screen", "fill_alpha": {"value": 0.5}, "line_width": {"value": 2}, "line_alpha": {"value": 1.0}, "level": "overlay"}, "type": "PolyAnnotation", "id": "bc6fbd0a-ff05-4685-915c-2997ddd9b744"}, {"attributes": {"overlay": {"type": "PolyAnnotation", "id": "0b25e0b2-d923-418e-b950-9cf8a8b99d31"}, "plot": {"subtype": "Figure", "type": "Plot", "id": "c1807ba5-ff2b-4ccd-bdab-70cd406e3f3e"}}, "type": "LassoSelectTool", "id": "cf59f36e-45a3-4359-ba31-7f6c38a ...
