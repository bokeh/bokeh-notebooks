# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>02. Basic Plotting Interface</h2></div>

# %% [markdown]
# This section of the tutorial covers the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html)
# interface. This interface is a "mid-level" interface, and the main idea can be described by the statement:
#
# **Starting from simple default figures (with sensible default tools, grids and axes), add markers and other shapes whose visual attributes are tied to directly data.**
#
# We will see that it is possible to customize and change all of the defaults, but having them means that it is possible to get up and running very quickly.

# %% [markdown]
# # Imports and Setup
#
# When using the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) interface, there are a few common imports:
# * Use the [`figure`](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.figure) function to  create new plot objects to work with.
# * Call the functions [`output_file`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_file), [`output_notebook`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_notebook), and [`output_server`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_server) (possibly in combination) to tell Bokeh how to display or save output.
# * Execute [`show`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.show) and  [`save`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.save) to display or save plots and layouts.

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %% [markdown]
# In this case, we are in the Jupyter notebook, so call `output_notebook()`. We only need to call this once, and all subsequent calls to `show()` will display inline in the notebook.

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f7208f9c-e386-4211-8d79-a6fd631b952d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Some Basic Scatter Plots
#
# In this section you will see how to use Bokeh's various marker types to create simple scatter plots.

# %%
# create a new plot with default tools, using figure
p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=15, line_color="navy", fill_color="orange", fill_alpha=0.5)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5d0c4d1f-24df-4954-a2bd-ec653f7d377f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5d0c4d1f-24df-4954-a2bd-ec653f7d377f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5d0c4d1f-24df-4954-a2bd-ec653f7d377f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5d0c4d1f-24df-4954-a2bd-ec653f7d377f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"303d903e-13ea-4744-8a64-a6e25ab346b7":{"roots":{"references":[{"attributes":{"plot":{"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"}},"id":"bca86e4a-b639-4e7b-b747-22ca1654e44d","type":"SaveTool"},{"attributes":{},"id":"140549fb-0241-4b1b-9ea4-3be3009d5d12","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"72a1c235-c2ee-4f56-8948-be5282da50ef","type":"BasicTickFormatter"},"plot":{"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"},"ticker":{"id":"bafc7295-abb9-4ea2-93c0-a670a9c8a6db","type":"BasicTicker"}},"id":"bce20a8e-4d9b-4980-a681-e29d9a0560bf","type":"LinearAxis"},{"attributes":{"below":[{"id":"bce20a8e-4d9b-4980-a681-e29d9a0560bf","type":"LinearAxis"}],"left":[{"id":"57f9f78b-90a8-4405-92cb-b808469ea02a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"bce20a8e-4d9b-4980-a681-e29d9a0560bf","type":"LinearAxis"},{"id":"e4946bed-50c2-4f9f-9faf-bca0aaf20212","type":"Grid"},{"id":"57f9f78b-90a8-4405-92cb-b808469ea02a","type":"LinearAxis"},{"id":"a710cb4a-6b2e-4431-88e4-fc84f04a3a7e","type":"Grid"},{"id":"e2050fbc-34f5-4f50-8a27-41e6ded70da3","type":"BoxAnnotation"},{"id":"ed82a842-4650-4fa9-b561-f2971bd49374","type":"GlyphRenderer"}],"title":{"id":"b0cc32bf-7085-4261-8926-970c1100e6fc","type":"Title"},"tool_events":{"id":"647a356b-6fde-4cc0-9418-7e4e09c975b3","type":"ToolEvents"},"toolbar":{"id":"3fe6d551-b57d-4d32-947a-e7c3f09e9a29","type":"Toolbar"},"x_range":{"id":"e6faf6c9-ffd7-4ff6-8c11-303cbb051c5b","type":"DataRange1d"},"y_range":{"id":"4e0234c9-52d4-4832-b79d-378631d637d7","type":"DataRange1d"}},"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"e6faf6c9-ffd7-4ff6-8c11-303cbb051c5b","type":"DataRange1d"},{"attributes":{"plot":{"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"}},"id":"d3c8f640-1d25-4efa-bf29-a5d7222938d7","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"605a747c-9863-4172-b24e-f640b6007514","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7be9669c-c4a9-4494-932f-8a009fb39649","type":"PanTool"},{"id":"831810df-f94c-4b57-b271-a7b1e885b435","type":"WheelZoomTool"},{"id":"8dc2f36a-76d1-46b4-84f1-ea7d5fb3ba51","type":"BoxZoomTool"},{"id":"bca86e4a-b639-4e7b-b747-22ca1654e44d","type":"SaveTool"},{"id":"8a34553a-9bb5-4d67-b261-c06ab701a918","type":"ResetTool"},{"id":"d3c8f640-1d25-4efa-bf29-a5d7222938d7","type":"HelpTool"}]},"id":"3fe6d551-b57d-4d32-947a-e7c3f09e9a29","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e0b2d43-fc77-4333-8322-a4a825b5ff57","type":"Circle"},{"attributes":{"plot":{"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"}},"id":"7be9669c-c4a9-4494-932f-8a009fb39649","type":"PanTool"},{"attributes":{},"id":"0b394085-0523-4666-b042-7b4c4f3453da","type":"BasicTicker"},{"attributes":{"formatter":{"id":"140549fb-0241-4b1b-9ea4-3be3009d5d12","type":"BasicTickFormatter"},"plot":{"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"},"ticker":{"id":"0b394085-0523-4666-b042-7b4c4f3453da","type":"BasicTicker"}},"id":"57f9f78b-90a8-4405-92cb-b808469ea02a","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"orange"},"line_color":{"value":"navy"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"f07ef810-7cd8-4420-a830-38911a651d2c","type":"Circle"},{"attributes":{"plot":{"id":"3603bda6-ce1c-46c2-8adc-477118e79b15","subtype":"Figure","type":"Plot"}},"id":"831810df-f94c-4b57-b271-a7b1e885b435","type":"WheelZoomTool"},{"attributes":{"bottom_units":"sc ...

# %% [markdown]
# All Bokeh markers accept `size` (measured in screen space units) as a property. Circles also have `radius` (measured in "data" space units).

# %%
# EXERCISE: Try changing the example above to set a `radius` value instead of `size`

# %% [markdown]
# To scatter square markers instead of circles, you can use the `square` method on figures.

# %%
# create a new plot using figure
p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, alpha, and sizes
p.square([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=[10, 15, 20, 25, 30], color="firebrick", alpha=0.6)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2239fbfd-266c-4b8a-8d60-a0b8c8f9f67b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#2239fbfd-266c-4b8a-8d60-a0b8c8f9f67b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2239fbfd-266c-4b8a-8d60-a0b8c8f9f67b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2239fbfd-266c-4b8a-8d60-a0b8c8f9f67b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4d029e80-6a28-4414-b347-d2eff8e791eb":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"271c9d6c-01f4-420f-b7d8-3c2fec565178","type":"Square"},{"attributes":{"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"}},"id":"62918794-5ca3-4566-b283-0f1a1a9ca305","type":"WheelZoomTool"},{"attributes":{},"id":"fa82ec8e-df4c-428f-a2cc-afee4fdbd8b9","type":"BasicTicker"},{"attributes":{"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"}},"id":"0e7390ed-3e6c-4d70-a8a1-69acbada2ce7","type":"PanTool"},{"attributes":{"formatter":{"id":"d503d6c9-4931-4508-9b77-0b3c69865770","type":"BasicTickFormatter"},"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"},"ticker":{"id":"fa82ec8e-df4c-428f-a2cc-afee4fdbd8b9","type":"BasicTicker"}},"id":"08136954-3f3d-406f-b40a-a6e295eee9d8","type":"LinearAxis"},{"attributes":{"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"}},"id":"a8abe74d-f488-4f94-aa82-c88677d4039a","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"firebrick"},"line_alpha":{"value":0.6},"line_color":{"value":"firebrick"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f850eec-03ec-443e-93d9-dd787795f5cd","type":"Square"},{"attributes":{"formatter":{"id":"bd96745d-0c0b-4b6f-8f65-954d39affab2","type":"BasicTickFormatter"},"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b335348-8e7f-4efc-9f3b-53d6c2afcf35","type":"BasicTicker"}},"id":"71f880a7-5664-4e94-9524-deafc4d69f0b","type":"LinearAxis"},{"attributes":{"data_source":{"id":"52bd0f41-8bf1-41b6-b079-5b5edd436185","type":"ColumnDataSource"},"glyph":{"id":"9f850eec-03ec-443e-93d9-dd787795f5cd","type":"Square"},"hover_glyph":null,"nonselection_glyph":{"id":"271c9d6c-01f4-420f-b7d8-3c2fec565178","type":"Square"},"selection_glyph":null},"id":"558b72e2-d53a-4fd6-b6db-c7b38a672060","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"}},"id":"10520799-b639-4cae-92da-b1656e57c4b6","type":"SaveTool"},{"attributes":{"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b335348-8e7f-4efc-9f3b-53d6c2afcf35","type":"BasicTicker"}},"id":"5ee896c2-44d1-4a55-84ae-e4db12ef9fd5","type":"Grid"},{"attributes":{"callback":null},"id":"8785b5f4-81bb-4e07-87e9-26f24771f4ee","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["size","y","x"],"data":{"size":[10,15,20,25,30],"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"52bd0f41-8bf1-41b6-b079-5b5edd436185","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"7c55d08e-92fa-4afb-b414-298f7c1bf891","subtype":"Figure","type":"Plot"},"ticker":{"id":"fa82ec8e-df4c-428f-a2cc-afee4fdbd8b9","type":"BasicTicker"}},"id":"89bcd751-1448-4160-adb2-e70dd6e1d383","type":"Grid"},{"attributes":{},"id":"d503d6c9-4931-4508-9b77-0b3c69865770","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":null},"id":"d6e1b8a5-0aec-4bea-8249-a38de2055bc3","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"58179480-fbc8-421b-afbf-7dde70395aa9","type":"BoxAnnotation"},{"attributes":{},"id":"db803b9e-ae6a-44f5-9175-c276a3328865","type":"ToolEvents"},{"attributes":{},"id":"bd96745d-0c0b-4b6f-8f65-954d39affab2","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"ead6159d-87b ...

# %% [markdown]
# Note that in the example above, we are also specifying different sizes for each individual marker. ***In general, all of a glyph's properties can be "vectorized" in this fashion. ***  Also note that we have passed ``color`` as a shorthand to set both the line and fill colors easily at the same time. This is a convenience specific to ``bokeh.plotting``.
#
# </table><p>There are many marker types available in Bokeh, you can see details and
# example plots for all of them in the reference guide by clicking on entries in the list below:</p>
# <table class="hlist" style="float:left"><tr><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.asterisk" title="bokeh.plotting.Figure.asterisk"><code class="xref py py-func docutils literal"><span class="pre">asterisk()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle" title="bokeh.plotting.Figure.circle"><code class="xref py py-func docutils literal"><span class="pre">circle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_cross" title="bokeh.plotting.Figure.circle_cross"><code class="xref py py-func docutils literal"><span class="pre">circle_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_x" title="bokeh.plotting.Figure.circle_x"><code class="xref py py-func docutils literal"><span class="pre">circle_x()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.cross" title="bokeh.plotting.Figure.cross"><code class="xref py py-func docutils literal"><span class="pre">cross()</span></code></a></li>
# </ul>
# </td><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond" title="bokeh.plotting.Figure.diamond"><code class="xref py py-func docutils literal"><span class="pre">diamond()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond_cross" title="bokeh.plotting.Figure.diamond_cross"><code class="xref py py-func docutils literal"><span class="pre">diamond_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.inverted_triangle" title="bokeh.plotting.Figure.inverted_triangle"><code class="xref py py-func docutils literal"><span class="pre">inverted_triangle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square" title="bokeh.plotting.Figure.square"><code class="xref py py-func docutils literal"><span class="pre">square()</span></code></a></li>
# </ul>
# </td><td><ul>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_cross" title="bokeh.plotting.Figure.square_cross"><code class="xref py py-func docutils literal"><span class="pre">square_cross()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_x" title="bokeh.plotting.Figure.square_x"><code class="xref py py-func docutils literal"><span class="pre">square_x()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.triangle" title="bokeh.plotting.Figure.triangle"><code class="xref py py-func docutils literal"><span class="pre">triangle()</span></code></a></li>
# <li><a href="http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.x" title="bokeh.plotting.Figure.x"><code class="xref py py-func docutils literal"><span class="pre">x()</span></code></a></li>
# </ul>
# </td></tr></table>

# %%
# EXERCISE: Plot some different markers in this cell

# %% [markdown]
# # Basic Line Plots

# %%
# create a new plot (with a title) using figure
p = figure(plot_width=400, plot_height=400, title="My Line Plot")

# add a line renderer
p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], line_width=2)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0853da4d-9d81-4938-82ee-18a8126b19f3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0853da4d-9d81-4938-82ee-18a8126b19f3").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0853da4d-9d81-4938-82ee-18a8126b19f3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0853da4d-9d81-4938-82ee-18a8126b19f3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"feb5fbfc-b363-40a6-b911-995dc2cdb229":{"roots":{"references":[{"attributes":{"callback":null},"id":"401811e1-4ee6-4564-bb43-1b2333f4176f","type":"DataRange1d"},{"attributes":{"below":[{"id":"21b986f0-867d-4937-b52e-03aaa10d650e","type":"LinearAxis"}],"left":[{"id":"85fb6720-1ea7-4ddd-9c2e-16b2305af6e1","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"21b986f0-867d-4937-b52e-03aaa10d650e","type":"LinearAxis"},{"id":"3df05a76-d1dc-4ec2-afa7-383896b3f56e","type":"Grid"},{"id":"85fb6720-1ea7-4ddd-9c2e-16b2305af6e1","type":"LinearAxis"},{"id":"ef4c1005-d4ef-45f6-9b07-42d520cafe5d","type":"Grid"},{"id":"cdcdb086-705b-4f06-8799-40d7399a5e9f","type":"BoxAnnotation"},{"id":"42bfc361-d673-4e1a-9b43-337528a861b8","type":"GlyphRenderer"}],"title":{"id":"f11735c0-0366-4aa5-8a11-dc2847cdb8fc","type":"Title"},"tool_events":{"id":"7d503dd0-274a-49a1-808b-b2af419f5f1e","type":"ToolEvents"},"toolbar":{"id":"ca349d92-1b1d-49ad-98ba-3630fd108f3e","type":"Toolbar"},"x_range":{"id":"401811e1-4ee6-4564-bb43-1b2333f4176f","type":"DataRange1d"},"y_range":{"id":"4ef37e7f-963b-46a9-a4d7-254b5db8547f","type":"DataRange1d"}},"id":"f98ee5e4-a62a-4966-ab46-57739ab029ab","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7d503dd0-274a-49a1-808b-b2af419f5f1e","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"f98ee5e4-a62a-4966-ab46-57739ab029ab","subtype":"Figure","type":"Plot"},"ticker":{"id":"afb5c72f-461e-4374-9188-7e5ff27d9b7c","type":"BasicTicker"}},"id":"ef4c1005-d4ef-45f6-9b07-42d520cafe5d","type":"Grid"},{"attributes":{"overlay":{"id":"cdcdb086-705b-4f06-8799-40d7399a5e9f","type":"BoxAnnotation"},"plot":{"id":"f98ee5e4-a62a-4966-ab46-57739ab029ab","subtype":"Figure","type":"Plot"}},"id":"a9b00894-d6ac-4fb2-bcef-6cec55231dc9","type":"BoxZoomTool"},{"attributes":{},"id":"22327091-0754-414d-85d6-d771a79a1374","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cdcdb086-705b-4f06-8799-40d7399a5e9f","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b80f474d-fa25-4b85-90d9-29bb180d5c46","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8124ccc4-c788-47e1-89a0-36dbba704874","type":"PanTool"},{"id":"84b6e1f5-b338-48b7-82f6-1281e1938363","type":"WheelZoomTool"},{"id":"a9b00894-d6ac-4fb2-bcef-6cec55231dc9","type":"BoxZoomTool"},{"id":"9a8088a9-79fc-420f-950f-b0113fe1de21","type":"SaveTool"},{"id":"e38f74df-5cc2-440a-a036-0c7292e77681","type":"ResetTool"},{"id":"9a15f7b0-bfc6-4517-a900-c8d3341f32f9","type":"HelpTool"}]},"id":"ca349d92-1b1d-49ad-98ba-3630fd108f3e","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a491dfb-a569-4aaa-93e3-c892afd34751","type":"Line"},{"attributes":{"plot":{"id":"f98ee5e4-a62a-4966-ab46-57739ab029ab","subtype":"Figure","type":"Plot"}},"id":"9a8088a9-79fc-420f-950f-b0113fe1de21","type":"SaveTool"},{"attributes":{"formatter":{"id":"0b11a119-149b-4612-a46b-f67807ec6eef","type":"BasicTickFormatter"},"plot":{"id":"f98ee5e4-a62a-4966-ab46-57739ab029ab","subtype":"Figure","type":"Plot"},"ticker":{"id":"db306c39-5099-46e1-b807-b5e2d53483bc","type":"BasicTicker"}},"id":"21b986f0-867d-4937-b52e-03aaa10d650e","type":"LinearAxis"},{"attributes":{"data_source":{"id":"be260ad3-afa6-48c9-8718-79c100069617","type":"ColumnDataSource"},"glyph":{"id":"b80f474d-fa25-4b85-90d9-29bb180d5c46","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"3a491dfb-a569-4aaa-93e3-c892afd34751","type":"Line"},"selection_glyph":nul ...

# %% [markdown]
# # Images

# %% [markdown]
# The example below shows how to use the `image_rgba` method to display raw RGBA data.
#
# **Note**: This example makes use of the NumPy library

# %%
from __future__ import division
import numpy as np

# set up some data
N = 20
img = np.empty((N,N), dtype=np.uint32)
view = img.view(dtype=np.uint8).reshape((N, N, 4))
for i in range(N):
    for j in range(N):
        view[i, j, 0] = int(i/N*255) # red
        view[i, j, 1] = 158          # green
        view[i, j, 2] = int(j/N*255) # blue
        view[i, j, 3] = 255          # alpha
        
# create a new plot (with a fixed range) using figure
p = figure(x_range=[0,10], y_range=[0,10])

# add an RGBA image renderer
p.image_rgba(image=[img], x=[0], y=[0], dw=[10], dh=[10])

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="41358aa4-15d5-446d-9ed9-04fdb7a69aa1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#41358aa4-15d5-446d-9ed9-04fdb7a69aa1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41358aa4-15d5-446d-9ed9-04fdb7a69aa1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41358aa4-15d5-446d-9ed9-04fdb7a69aa1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"369b4f0a-11c5-4ddc-9deb-ee48602613c2":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"cc54987b-538a-46ea-bd3f-8a12adbc06c7","type":"Title"},{"attributes":{"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd4c585d-96a7-48b3-8af6-3c6fa57d8d4c","type":"BasicTicker"}},"id":"04d60c23-0741-4029-a0ea-5c2715d845c2","type":"Grid"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"66d2655f-868b-477c-b862-504e7ff79810","type":"ImageRGBA"},{"attributes":{},"id":"1fec0517-9fb2-4992-bbff-192e66278dd4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"}},"id":"5272548d-75dd-45d6-a32a-dd588d51c563","type":"PanTool"},{"attributes":{},"id":"faf42dcf-6941-4b80-86ac-e8ccef479f96","type":"BasicTicker"},{"attributes":{"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"}},"id":"16d4d0e0-6c4d-4bcf-8b86-1e921c3949c1","type":"WheelZoomTool"},{"attributes":{},"id":"fd4c585d-96a7-48b3-8af6-3c6fa57d8d4c","type":"BasicTicker"},{"attributes":{"callback":null,"end":10},"id":"0ccfd17c-c67a-45e4-b7ea-4767ae8bc494","type":"Range1d"},{"attributes":{},"id":"43af1d59-1080-4828-a4bc-5700042e2009","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"43af1d59-1080-4828-a4bc-5700042e2009","type":"BasicTickFormatter"},"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd4c585d-96a7-48b3-8af6-3c6fa57d8d4c","type":"BasicTicker"}},"id":"55d68b97-2e9e-45a6-a376-ee0b7707b4d4","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ce570442-170b-4a66-955d-921c1c8a5ab3","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"},"ticker":{"id":"faf42dcf-6941-4b80-86ac-e8ccef479f96","type":"BasicTicker"}},"id":"db824790-1527-44ad-a1dd-6b2014367e1d","type":"Grid"},{"attributes":{"overlay":{"id":"ce570442-170b-4a66-955d-921c1c8a5ab3","type":"BoxAnnotation"},"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"}},"id":"7f478eda-126c-4148-8ed3-9fda82ad302a","type":"BoxZoomTool"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"70834ea3-68c7-49c3-8917-f9e40fa0959f","type":"ImageRGBA"},{"attributes":{"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"}},"id":"718eb401-cdee-4245-bab3-71707bce5c7d","type":"HelpTool"},{"attributes":{"formatter":{"id":"1fec0517-9fb2-4992-bbff-192e66278dd4","type":"BasicTickFormatter"},"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"},"ticker":{"id":"faf42dcf-6941-4b80-86ac-e8ccef479f96","type":"BasicTicker"}},"id":"9157b306-8144-4001-bb11-88c8668a23d8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"91cfc4c2-ff1a-450a-a1cf-1cd28a7e73ec","type":"ColumnDataSource"},"glyph":{"id":"70834ea3-68c7-49c3-8917-f9e40fa0959f","type":"ImageRGBA"},"hover_glyph":null,"nonselection_glyph":{"id":"66d2655f-868b-477c-b862-504e7ff79810","type":"ImageRGBA"},"selection_glyph":null},"id":"e35e3d81-dc0a-428b-a81e-cabe8092f700","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"31dde84c-7416-4516-a73b-80a7edb12da0","subtype":"Figure","type":"Plot"}},"id":"b923dc50-9912-4d88-ada2-25e1bbee1eaa","type":"ResetTool"},{"attributes":{"below":[{"id":"55d68b97-2e9e-45a6-a376-ee0b7707b4d4","type":"LinearAxis"}],"left":[{"id":"9157b306-8144 ...

# %% [markdown]
# # Other Kinds of Glyphs
#
# Bokeh supports many other kinds of glyphs. You can click on the User Guide links below to see how to create plots with these glyphs using the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) interface.
#
# * [Rectangles and Ovals](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#rectangles-and-ovals)
# * [Segments and Rays](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#segments-and-rays)
# * [Wedges and Arcs](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#wedges-and-arcs)
# * [Specialized Curves](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html#specialized-curves)

# %%
# EXERCISE: Plot some of the other glyph types, following the examples in the User Guide.

# %% [markdown]
# # Plots with Multiple Glyphs
#
# It is possible to combine more than one glyph on a single figure. You just need to call multiple glyph methods on one figure object:

# %%
# set up some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 7, 3]

# create a new plot with figure
p = figure(plot_width=400, plot_height=400)

# add both a line and circles on the same plot
p.line(x, y, line_width=2)
p.circle(x, y, fill_color="white", size=8)

show(p) # show the results
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="226afa05-44fe-42c2-a899-fd3b582063d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#226afa05-44fe-42c2-a899-fd3b582063d2").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("226afa05-44fe-42c2-a899-fd3b582063d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '226afa05-44fe-42c2-a899-fd3b582063d2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"36b976fa-10f6-49fa-a912-9b789a0e247a":{"roots":{"references":[{"attributes":{"plot":{"id":"83e075fb-168d-4709-9db7-57d5ce16e6df","subtype":"Figure","type":"Plot"}},"id":"c9e21455-5f29-4646-8c0d-a937a8d35838","type":"SaveTool"},{"attributes":{"callback":null},"id":"1c94e238-ac74-468d-a732-83fb3a9c64a7","type":"DataRange1d"},{"attributes":{},"id":"7eeca85d-fe08-4d3d-a389-c187220ab11d","type":"BasicTicker"},{"attributes":{"plot":{"id":"83e075fb-168d-4709-9db7-57d5ce16e6df","subtype":"Figure","type":"Plot"}},"id":"aaf51b97-98cb-423b-ac0b-3522c60411cd","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"251851d4-7b40-4b63-a97a-da76029821b4","type":"ColumnDataSource"},"glyph":{"id":"77e33c68-efc8-4087-9c5e-a18411db45d1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"95a45f16-01b0-41e5-845b-ccca638c3afc","type":"Circle"},"selection_glyph":null},"id":"f139129b-9ee4-4337-8302-8f5574d8e833","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"da92f991-de67-436e-8f34-f0998041d740","type":"ColumnDataSource"},"glyph":{"id":"a23792a7-ffa2-4f66-9efb-2ac61d970bb2","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"7d77e4c8-3987-45b3-898b-4013ec014147","type":"Line"},"selection_glyph":null},"id":"2b301dc0-992b-4b73-b0c2-80f8ff86a63f","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a41d7590-da50-4aa3-820b-94fa9efc435c","type":"BoxAnnotation"},{"attributes":{},"id":"b1b17e1a-0d7a-47be-bba0-c414826cc660","type":"BasicTickFormatter"},{"attributes":{},"id":"502a50a8-a640-4133-a789-4d59a75c3430","type":"ToolEvents"},{"attributes":{"plot":{"id":"83e075fb-168d-4709-9db7-57d5ce16e6df","subtype":"Figure","type":"Plot"}},"id":"738459f1-1783-4b85-8552-75cd60a8a40e","type":"PanTool"},{"attributes":{"plot":{"id":"83e075fb-168d-4709-9db7-57d5ce16e6df","subtype":"Figure","type":"Plot"}},"id":"802350aa-0ef6-43b4-be10-fd515014c880","type":"HelpTool"},{"attributes":{"plot":null,"text":null},"id":"e4f0e90b-7800-478c-9de7-4816c15acc4a","type":"Title"},{"attributes":{"plot":{"id":"83e075fb-168d-4709-9db7-57d5ce16e6df","subtype":"Figure","type":"Plot"}},"id":"dbbfa538-f003-4b07-9f78-1ba1430ac5d3","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a23792a7-ffa2-4f66-9efb-2ac61d970bb2","type":"Line"},{"attributes":{"below":[{"id":"a0cb6a32-9a7a-492c-898c-1b5c7afb4716","type":"LinearAxis"}],"left":[{"id":"3103e2a9-020b-4438-b513-02fe9b78d5ef","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a0cb6a32-9a7a-492c-898c-1b5c7afb4716","type":"LinearAxis"},{"id":"03028e32-350e-4b39-aa3d-e39027cc07ca","type":"Grid"},{"id":"3103e2a9-020b-4438-b513-02fe9b78d5ef","type":"LinearAxis"},{"id":"fb45ab47-ccf2-4f0e-9e0d-0a11ac6ada22","type":"Grid"},{"id":"a41d7590-da50-4aa3-820b-94fa9efc435c","type":"BoxAnnotation"},{"id":"2b301dc0-992b-4b73-b0c2-80f8ff86a63f","type":"GlyphRenderer"},{"id":"f139129b-9ee4-4337-8302-8f5574d8e833","type":"GlyphRenderer"}],"title":{"id":"e4f0e90b-7800-478c-9de7-4816c15acc4a","type":"Title"},"tool_events":{"id":"502a50a8-a640-4133-a789-4d59a75c3430","type":"ToolEvents"},"toolbar":{"id":"2119bf34-8c3e-4f97-8b27-5405c963c8a0","type":"Toolbar"},"x_range":{"id":"a15091c1-3bd3-426c-8f95-6fbb892a78ca","type":"DataRange1d"},"y_range":{"id":"1c94e238-ac74-468d-a732-83fb3a9c64a7","type":"DataRange1d"}},"id":"83e075fb-168d-4709-9db7-57d5ce16e6df","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":" ...

# %%
# EXERCISE: create your own plot combining multiple glyphs together
