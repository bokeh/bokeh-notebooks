# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none; background-color: #ffffff">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>09. Geographic Plots</h2></div>

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="332f3fa8-ba51-4cdd-9915-ec297efeecb5">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# It is often useful to be able to relate datasets with their real-world context.  You can plot geographic data just like any other type of data, as in the [Texas Unemployment example](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/gallery/texas.ipynb), but Bokeh also Bokeh provides several specialized mechanisms for plotting data in geographic coordinates:
#
# * [GMapPlot](https://bokeh.pydata.org/en/latest/docs/user_guide/geo.html#google-maps-support): Bokeh Plots on top of Google Maps
#
# * [TileSource](https://bokeh.pydata.org/en/latest/docs/user_guide/geo.html#tile-providers), especially WMTSTileSource: allows data to be overlaid on data from any map tile server, including
# [Google Maps](http://maps.google.com),
# [Stamen](http://maps.stamen.com),
# [MapQuest](https://www.mapquest.com/),
# [OpenStreetMap](https://www.openstreetmap.org),
# [ESRI](http://www.esri.com),
# and custom servers.
#
# * [GeoJSONDataSource](https://bokeh.pydata.org/en/dev/docs/user_guide/geo.html#geojson-datasource): Allows reading data in [GeoJSON](http://geojson.org/) format for use with Bokeh plots and glyphs, similar to `ColumnDataSource`.

# %% [markdown]
# ## WMTS Tile Source
#
# WTMS is the most common web standard for tiled map data, i.e. maps supplied as standard-sized image patches from which the overall map can be constructed at a given zoom level.  WTMS uses Web Mercator format, measuring distances from Greenwich, England as meters north and meters west, which is easy to compute but does distort the global shape.
#
# First let's create an empty Bokeh plot covering the USA, with bounds specified in meters:

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource

# web mercator coordinates
USA = x_range,y_range = ((-13884029,-7453304), (2698291,6455972))

p = figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
p.axis.visible = False

# %% [markdown]
# A few WTMS tile sources are already defined in `bokeh.tile_providers`, but here we'll show how to specify the interface using a format string showing Bokeh how to request a tile with the required zoom, x, and y values from a given tile provider:

# %%
url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Tiles by Carto, under CC BY 3.0. Data by OSM, under ODbL"

p.add_tile(WMTSTileSource(url=url, attribution=attribution))
# Out:
# TileRenderer(id='25349dc1-ffc4-4ad6-97cc-7c8485687c40', ...)

# %% [markdown]
# If you show the figure, you can then use the wheel zoom and pan tools to navigate over any zoom level, and Bokeh will request the appropriate tiles from the server and insert them at the correct locations in the plot:

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc53b585-edd3-4c82-a588-8eeee8aff2b3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("fc53b585-edd3-4c82-a588-8eeee8aff2b3");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc53b585-edd3-4c82-a588-8eeee8aff2b3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc53b585-edd3-4c82-a588-8eeee8aff2b3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"327697ac-3ec3-45e3-9362-167a9c214fb2":{"roots":{"references":[{"attributes":{"callback":null,"end":6455972,"start":2698291},"id":"387ec79d-dd10-4000-9cae-2773b7b8cba3","type":"Range1d"},{"attributes":{},"id":"c4f7663d-252e-4bdb-bb4a-88d12558e8ca","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"02bf3d18-65f7-4397-98cb-d96e99aba332","type":"PanTool"},{"id":"bbdfc493-5b55-478d-8d1c-21c6a81ac0d8","type":"WheelZoomTool"}]},"id":"16240a65-345f-418b-8fb7-d2ea9c2bba83","type":"Toolbar"},{"attributes":{},"id":"619eba1c-9ccb-4641-b2fe-6b821068dc10","type":"LinearScale"},{"attributes":{},"id":"6a044fce-1820-45bd-bf8a-9bf86229f6f5","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"6a044fce-1820-45bd-bf8a-9bf86229f6f5","type":"BasicTickFormatter"},"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"69ae56e9-8073-4131-acdb-c05b419fdf27","type":"BasicTicker"},"visible":false},"id":"6908893f-9224-48e7-a5b4-e781a0ac9780","type":"LinearAxis"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"ee6090aa-8678-45c8-879f-402078e467d2","type":"Range1d"},{"attributes":{},"id":"8f85c265-1ed0-45d3-aa83-bbde756c6c9d","type":"BasicTickFormatter"},{"attributes":{"attribution":"Tiles by Carto, under CC BY 3.0. Data by OSM, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"b7f64f73-5cae-476c-8a8f-7805bf664d23","type":"WMTSTileSource"},{"attributes":{},"id":"69ae56e9-8073-4131-acdb-c05b419fdf27","type":"BasicTicker"},{"attributes":{"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"69ae56e9-8073-4131-acdb-c05b419fdf27","type":"BasicTicker"}},"id":"5c244004-c86b-4e35-b5d5-c6aff9c0a144","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"11e0a4f6-e060-4f97-b794-5001ecb90bc6","type":"Title"},{"attributes":{"formatter":{"id":"8f85c265-1ed0-45d3-aa83-bbde756c6c9d","type":"BasicTickFormatter"},"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d85b874-4754-4d52-96a9-95b7f270902a","type":"BasicTicker"},"visible":false},"id":"122cdf94-82a6-4e48-b212-484e1317e201","type":"LinearAxis"},{"attributes":{"tile_source":{"id":"b7f64f73-5cae-476c-8a8f-7805bf664d23","type":"WMTSTileSource"}},"id":"25349dc1-ffc4-4ad6-97cc-7c8485687c40","type":"TileRenderer"},{"attributes":{},"id":"9d85b874-4754-4d52-96a9-95b7f270902a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d85b874-4754-4d52-96a9-95b7f270902a","type":"BasicTicker"}},"id":"abff4cb8-4e48-4d3e-81e4-168e2e0b621b","type":"Grid"},{"attributes":{},"id":"bbdfc493-5b55-478d-8d1c-21c6a81ac0d8","type":"WheelZoomTool"},{"attributes":{},"id":"02bf3d18-65f7-4397-98cb-d96e99aba332","type":"PanTool"},{"attributes":{"below":[{"id":"6908893f-9224-48e7-a5b4-e781a0ac9780","type":"LinearAxis"}],"left":[{"id":"122cdf94-82a6-4e48-b212-484e1317e201","type":"LinearAxis"}],"renderers":[{"id":"6908893f-9224-48e7-a5b4-e781a0ac9780","type":"LinearAxis"},{"id":"5c244004-c86b-4e35-b5d5-c6aff9c0a144","type":"Grid"},{"id":"122cdf94-82a6-4e48-b212-484e1317e201","type":"LinearAxis"},{"id":"abff4cb8-4e48-4d3e-81e4-168e2e0b621b","type":"Grid"},{"id":"25349dc1-ffc4-4ad6-97cc-7c8485687c40","type":"TileRenderer"}],"title":{"id":"11e0a4f6-e060-4f97-b794-5001ecb90bc6","type":"Title"},"toolbar":{"id":"16240a65-345f-418b-8fb7-d2ea9c2bba83","type":"Toolbar"},"x_range":{"id":"ee6090aa-8678-45c8-879f-402078e467d2","type":"Range1d"},"x_scale":{"id":"c4f7663d-252e-4bdb-bb4a-88d12558e8ca","type":"LinearScale"},"y_range":{"id":"387ec79d-dd10-4000-9cae-2773b7b8cba3","type":"Range1d"},"y_scale":{"id":"619eba1c-9ccb-4641-b2fe-6b821068dc10","type":"LinearScale"}},"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","t ...
#             var render_items = [{"docid":"327697ac-3ec3-45e3-9362-167a9c214fb2","elementid":"fc53b585-edd3-4c82-a588-8eeee8aff2b3","modelid":"c66a447b-8341-4258-81ae-1b2105a85a29"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);

# %% [markdown]
# That's all it takes to put map data into your plot!  Of course, you'll usually want to show other data as well, or you could just use the tile server's own web address. You can now add anything you would normally use in a Bokeh plot, as long as you can obtain coordinates for it in Web Mercator format.  For example:

# %%
import pandas as pd
import numpy as np

def wgs84_to_web_mercator(df, lon="lon", lat="lat"):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

df = pd.DataFrame(dict(name=["Austin", "NYC"], lon=[-97.7431,-74.0059], lat=[30.2672,40.7128]))
wgs84_to_web_mercator(df)
# Out:
#        lat      lon    name             x             y
# 0  30.2672 -97.7431  Austin -1.088071e+07  3.537942e+06
# 1  40.7128 -74.0059     NYC -8.238299e+06  4.970072e+06

# %%
p.circle(x=df['x'], y=df['y'], fill_color='orange', size=10)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="03c0fda1-11da-44c5-bc35-171b259d7d04"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("03c0fda1-11da-44c5-bc35-171b259d7d04");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("03c0fda1-11da-44c5-bc35-171b259d7d04");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '03c0fda1-11da-44c5-bc35-171b259d7d04' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4900a068-9d80-49da-a9b0-71f5c20b9458":{"roots":{"references":[{"attributes":{"callback":null,"end":6455972,"start":2698291},"id":"387ec79d-dd10-4000-9cae-2773b7b8cba3","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"TJjbA9nAZMGf/KLGNm1fwQ==","dtype":"float64","shape":[2]},"y":{"__ndarray__":"a6XdLQv+SkFnqxDllfVSQQ==","dtype":"float64","shape":[2]}}},"id":"b0ec426f-62e5-4f77-9579-9749e6e70e3f","type":"ColumnDataSource"},{"attributes":{},"id":"c4f7663d-252e-4bdb-bb4a-88d12558e8ca","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"02bf3d18-65f7-4397-98cb-d96e99aba332","type":"PanTool"},{"id":"bbdfc493-5b55-478d-8d1c-21c6a81ac0d8","type":"WheelZoomTool"}]},"id":"16240a65-345f-418b-8fb7-d2ea9c2bba83","type":"Toolbar"},{"attributes":{},"id":"619eba1c-9ccb-4641-b2fe-6b821068dc10","type":"LinearScale"},{"attributes":{},"id":"6a044fce-1820-45bd-bf8a-9bf86229f6f5","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"ee6090aa-8678-45c8-879f-402078e467d2","type":"Range1d"},{"attributes":{},"id":"8f85c265-1ed0-45d3-aa83-bbde756c6c9d","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"6a044fce-1820-45bd-bf8a-9bf86229f6f5","type":"BasicTickFormatter"},"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"69ae56e9-8073-4131-acdb-c05b419fdf27","type":"BasicTicker"},"visible":false},"id":"6908893f-9224-48e7-a5b4-e781a0ac9780","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"orange"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"3c62ad23-c2b1-4aa0-a6dc-eed5b36c620b","type":"Circle"},{"attributes":{"attribution":"Tiles by Carto, under CC BY 3.0. Data by OSM, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"b7f64f73-5cae-476c-8a8f-7805bf664d23","type":"WMTSTileSource"},{"attributes":{},"id":"69ae56e9-8073-4131-acdb-c05b419fdf27","type":"BasicTicker"},{"attributes":{"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"69ae56e9-8073-4131-acdb-c05b419fdf27","type":"BasicTicker"}},"id":"5c244004-c86b-4e35-b5d5-c6aff9c0a144","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"11e0a4f6-e060-4f97-b794-5001ecb90bc6","type":"Title"},{"attributes":{"formatter":{"id":"8f85c265-1ed0-45d3-aa83-bbde756c6c9d","type":"BasicTickFormatter"},"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d85b874-4754-4d52-96a9-95b7f270902a","type":"BasicTicker"},"visible":false},"id":"122cdf94-82a6-4e48-b212-484e1317e201","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5363443-e7e1-4cea-add5-42b011e955de","type":"Circle"},{"attributes":{"tile_source":{"id":"b7f64f73-5cae-476c-8a8f-7805bf664d23","type":"WMTSTileSource"}},"id":"25349dc1-ffc4-4ad6-97cc-7c8485687c40","type":"TileRenderer"},{"attributes":{},"id":"9d85b874-4754-4d52-96a9-95b7f270902a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c66a447b-8341-4258-81ae-1b2105a85a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d85b874-4754-4d52-96a9-95b7f270902a","type":"BasicTicker"}},"id":"abff4cb8-4e48-4d3e-81e4-168e2e0b621b","type":"Grid"},{"attributes":{},"id":"bbdfc493-5b55-478d-8d1c-21c6a81ac0d8","type":"WheelZoomTool"},{"attributes":{},"id":"02bf3d18-65f7-4397-98cb-d96e99aba332","type":"PanTool"},{"attributes":{"source":{"id":"b0ec426f-62e5-4f77-9579-9749e6e70e3f","type":"ColumnDataSource"}},"id":"aa6b1b4f-2ef0-41d9-a3bd-5492236db0fb","type":"CDSView"},{"attributes":{"data_source":{"id":"b0ec426f-62e5-4f77-9579-9749e6e70e3f" ...

# %%
# EXERCISE: find some data in lat, lon (e.g. at http://data.gov), 
# import it into a dataframe or data source, and add it on the map above.

# %% [markdown]
# ## GeoJSON
