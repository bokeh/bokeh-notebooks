# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="http://bokeh.pydata.org/">
#            <img
#                src="assets/images/bokeh-transparent.png"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>11. Geographic Data</h2></div>

# %% [markdown]
# It is often useful to be able to relate datasets with their real-world context.  You can plot geographic data just like any other type of data, as in the [Texas Unemployment example](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/gallery/texas.ipynb), but Bokeh also Bokeh provides several specialized mechanisms for plotting data in geographic coordinates:
#
# * [TileSource](http://bokeh.pydata.org/en/latest/docs/reference/models/tiles.html), especially WMTSTileSource: allows data to be overlaid on data from any map tile server, including [Google Maps](http://maps.google.com), [Stamen](http://maps.stamen.com), [MapQuest](https://www.mapquest.com/), [OpenStreetMap](https://www.openstreetmap.org), [ESRI](http://www.esri.com), and custom servers.
# * [GeoJSONDataSource](http://bokeh.pydata.org/en/0.11.1/docs/user_guide/geo.html#geojson-datasource): Allows reading data in [GeoJSON](http://geojson.org/) format and using it just like any other ColumnDataSource.
# * GMapPlot: older, more limited interface just to Google Maps (GMapPlot); obsoleted by TileSource.
#
# Here we will briefly demonstrate how to use a WTMS tile source along with your data.

# %% [markdown]
# # WMTS Tile Source
#
# WTMS is the most common web standard for tiled map data, i.e. maps supplied as standard-sized image patches from which the overall map can be constructed at a given zoom level.  WTMS uses Web Mercator format, measuring distances from Greenwich, England as meters north and meters west, which is easy to compute but does distort the global shape.
#
# First let's create an empty Bokeh plot covering the USA, with bounds specified in meters:

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0488d6dc-397e-4be0-b358-ec53583e0709">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource

USA = x_range,y_range = ((-13884029,-7453304), (2698291,6455972))

fig = figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False

# %% [markdown]
# A few WTMS tile sources are already defined in `bokeh.tile_providers`, but here we'll show how to specify the interface using a format string showing Bokeh how to request a tile with the required zoom, x, and y values from a given tile provider:

# %%
url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL"

fig.add_tile(WMTSTileSource(url=url, attribution=attribution))

# %% [markdown]
# If you show the figure, you can then use the wheel zoom and pan tools to navigate over any zoom level, and Bokeh will request the appropriate tiles from the server and insert them at the correct locations in the plot:

# %%
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="802d2798-bbc2-443a-9597-bdd75433865f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#802d2798-bbc2-443a-9597-bdd75433865f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("802d2798-bbc2-443a-9597-bdd75433865f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '802d2798-bbc2-443a-9597-bdd75433865f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3a015d20-a59e-4948-bd4c-a8a02d79efb5":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"91d15d6f-5b72-4b17-b421-d274e63b03e1","type":"Title"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"d5f519de-5749-430a-b082-ce16eefe2b4a","type":"Range1d"},{"attributes":{},"id":"53c22a32-145d-4e32-b6a6-e13bf80c5271","type":"BasicTicker"},{"attributes":{},"id":"19087a69-3a51-4a23-9b57-1595b861c674","type":"BasicTickFormatter"},{"attributes":{},"id":"2d26ea57-2aa1-4e52-bd2c-9ba5a2e5881b","type":"ToolEvents"},{"attributes":{"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"}},"id":"2150a49f-397f-4d99-b18d-4e401e6a5444","type":"PanTool"},{"attributes":{"below":[{"id":"747c5dc5-1396-49d0-bf4b-e3b578d0ec16","type":"LinearAxis"}],"left":[{"id":"9a4e4f1a-d4c9-4ab5-ba49-bea2094c5737","type":"LinearAxis"}],"renderers":[{"id":"747c5dc5-1396-49d0-bf4b-e3b578d0ec16","type":"LinearAxis"},{"id":"d0d823d9-35e8-41ba-984c-321837fc6703","type":"Grid"},{"id":"9a4e4f1a-d4c9-4ab5-ba49-bea2094c5737","type":"LinearAxis"},{"id":"cc1e7da7-5283-4010-a33b-6f66a0c3f1aa","type":"Grid"},{"id":"1693a88a-5257-40fa-b1b0-f507227349a1","type":"TileRenderer"}],"title":{"id":"91d15d6f-5b72-4b17-b421-d274e63b03e1","type":"Title"},"tool_events":{"id":"2d26ea57-2aa1-4e52-bd2c-9ba5a2e5881b","type":"ToolEvents"},"toolbar":{"id":"c3f59f6f-0069-4745-864d-a30062a4e2ff","type":"Toolbar"},"x_range":{"id":"d5f519de-5749-430a-b082-ce16eefe2b4a","type":"Range1d"},"y_range":{"id":"ac1728bd-4b77-4a68-b9c2-8291ce61de9a","type":"Range1d"}},"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"c29fb48a-fbeb-42f8-82db-c7789d1f6c5a","type":"BasicTicker"},{"attributes":{"tile_source":{"id":"8b4724fa-8d35-4e42-b516-e3ddc8fc9355","type":"WMTSTileSource"}},"id":"1693a88a-5257-40fa-b1b0-f507227349a1","type":"TileRenderer"},{"attributes":{"callback":null,"end":6455972,"start":2698291},"id":"ac1728bd-4b77-4a68-b9c2-8291ce61de9a","type":"Range1d"},{"attributes":{"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"}},"id":"9dbceff8-78eb-4052-8e0f-0e093054e56d","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"c29fb48a-fbeb-42f8-82db-c7789d1f6c5a","type":"BasicTicker"}},"id":"d0d823d9-35e8-41ba-984c-321837fc6703","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"53c22a32-145d-4e32-b6a6-e13bf80c5271","type":"BasicTicker"}},"id":"cc1e7da7-5283-4010-a33b-6f66a0c3f1aa","type":"Grid"},{"attributes":{},"id":"5a223488-2935-46a0-aad4-d807a2dfbfd0","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"19087a69-3a51-4a23-9b57-1595b861c674","type":"BasicTickFormatter"},"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"c29fb48a-fbeb-42f8-82db-c7789d1f6c5a","type":"BasicTicker"},"visible":false},"id":"747c5dc5-1396-49d0-bf4b-e3b578d0ec16","type":"LinearAxis"},{"attributes":{"formatter":{"id":"5a223488-2935-46a0-aad4-d807a2dfbfd0","type":"BasicTickFormatter"},"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"53c22a32-145d-4e32-b6a6-e13bf80c5271","type":"BasicTicker"},"visible":false},"id":"9a4e4f1a-d4c9-4ab5-ba49-bea2094c5737","type":"LinearAxis"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"8b4724fa-8d35-4e42-b516-e3ddc8fc9355","type":"WMTSTileSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2150a49f-397f-4d99-b18d-4e401e6a5444","type":"PanTool"},{"id":"9dbceff8-78eb-4052-8e0f-0e093054e56d","type":"WheelZoomTool"}]},"id":"c3f59f6f-0069-4745-864d-a30062a4e2ff"," ...
#             var render_items = [{"docid":"3a015d20-a59e-4948-bd4c-a8a02d79efb5","elementid":"802d2798-bbc2-443a-9597-bdd75433865f","modelid":"7943bac0-d611-45d8-ae6a-035a6e93ebca"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === "1")) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === "1") {
#           d

# %% [markdown]
# That's all it takes to put map data into your plot!  Of course, you'll usually want to show other data as well, or you could just use the tile server's own web address. You can now add anything you would normally use in a Bokeh plot, as long as you can obtain coordinates for it in Web Mercator format.  For example:

# %%
import pandas as pd
import numpy as np

def wgs84_to_web_mercator(df, lon="lon", lat="lat"):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

df = pd.DataFrame(dict(name=["Austin","NYC"],lon=[-97.7431,-74.0059],lat=[30.2672,40.7128]))
wgs84_to_web_mercator(df)
# Out:
#        lat      lon    name             x             y
# 0  30.2672 -97.7431  Austin -1.088071e+07  3.537942e+06
# 1  40.7128 -74.0059     NYC -8.238299e+06  4.970072e+06

# %%
fig.circle(x=df['x'], y=df['y'],fill_color='blue', size=10)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f723a2cf-2ac0-4c37-9b7d-e8959bce1a3d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f723a2cf-2ac0-4c37-9b7d-e8959bce1a3d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f723a2cf-2ac0-4c37-9b7d-e8959bce1a3d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f723a2cf-2ac0-4c37-9b7d-e8959bce1a3d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e85abe56-e8a4-407a-a213-69d8864e0e81":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"91d15d6f-5b72-4b17-b421-d274e63b03e1","type":"Title"},{"attributes":{"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"c29fb48a-fbeb-42f8-82db-c7789d1f6c5a","type":"BasicTicker"}},"id":"d0d823d9-35e8-41ba-984c-321837fc6703","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-10880712.12055602,-8238299.103697925],"y":[3537942.358326604,4970071.579142428]}},"id":"c72445dd-8dd2-44ab-a224-f7649528d23f","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"}},"id":"2150a49f-397f-4d99-b18d-4e401e6a5444","type":"PanTool"},{"attributes":{"tile_source":{"id":"8b4724fa-8d35-4e42-b516-e3ddc8fc9355","type":"WMTSTileSource"}},"id":"1693a88a-5257-40fa-b1b0-f507227349a1","type":"TileRenderer"},{"attributes":{},"id":"c29fb48a-fbeb-42f8-82db-c7789d1f6c5a","type":"BasicTicker"},{"attributes":{"callback":null,"end":6455972,"start":2698291},"id":"ac1728bd-4b77-4a68-b9c2-8291ce61de9a","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"53c22a32-145d-4e32-b6a6-e13bf80c5271","type":"BasicTicker"}},"id":"cc1e7da7-5283-4010-a33b-6f66a0c3f1aa","type":"Grid"},{"attributes":{},"id":"2d26ea57-2aa1-4e52-bd2c-9ba5a2e5881b","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d1dbc33-d614-40f6-8838-586ded7637cd","type":"Circle"},{"attributes":{"formatter":{"id":"5a223488-2935-46a0-aad4-d807a2dfbfd0","type":"BasicTickFormatter"},"plot":{"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},"ticker":{"id":"53c22a32-145d-4e32-b6a6-e13bf80c5271","type":"BasicTicker"},"visible":false},"id":"9a4e4f1a-d4c9-4ab5-ba49-bea2094c5737","type":"LinearAxis"},{"attributes":{},"id":"53c22a32-145d-4e32-b6a6-e13bf80c5271","type":"BasicTicker"},{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"d5f519de-5749-430a-b082-ce16eefe2b4a","type":"Range1d"},{"attributes":{},"id":"19087a69-3a51-4a23-9b57-1595b861c674","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2150a49f-397f-4d99-b18d-4e401e6a5444","type":"PanTool"},{"id":"9dbceff8-78eb-4052-8e0f-0e093054e56d","type":"WheelZoomTool"}]},"id":"c3f59f6f-0069-4745-864d-a30062a4e2ff","type":"Toolbar"},{"attributes":{"below":[{"id":"747c5dc5-1396-49d0-bf4b-e3b578d0ec16","type":"LinearAxis"}],"left":[{"id":"9a4e4f1a-d4c9-4ab5-ba49-bea2094c5737","type":"LinearAxis"}],"renderers":[{"id":"747c5dc5-1396-49d0-bf4b-e3b578d0ec16","type":"LinearAxis"},{"id":"d0d823d9-35e8-41ba-984c-321837fc6703","type":"Grid"},{"id":"9a4e4f1a-d4c9-4ab5-ba49-bea2094c5737","type":"LinearAxis"},{"id":"cc1e7da7-5283-4010-a33b-6f66a0c3f1aa","type":"Grid"},{"id":"1693a88a-5257-40fa-b1b0-f507227349a1","type":"TileRenderer"},{"id":"94c188ca-2ecd-4b6b-93a0-d14575ab7986","type":"GlyphRenderer"}],"title":{"id":"91d15d6f-5b72-4b17-b421-d274e63b03e1","type":"Title"},"tool_events":{"id":"2d26ea57-2aa1-4e52-bd2c-9ba5a2e5881b","type":"ToolEvents"},"toolbar":{"id":"c3f59f6f-0069-4745-864d-a30062a4e2ff","type":"Toolbar"},"x_range":{"id":"d5f519de-5749-430a-b082-ce16eefe2b4a","type":"Range1d"},"y_range":{"id":"ac1728bd-4b77-4a68-b9c2-8291ce61de9a","type":"Range1d"}},"id":"7943bac0-d611-45d8-ae6a-035a6e93ebca","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"c72445dd-8dd2-44ab-a224-f7649528d23f","type":"ColumnDataSource"},"glyph":{"id":"0179d1af-36e4-4623-962e-836fa657f7fe","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1d1dbc33-d614-40f6-8838-586ded7637cd","type" ...

# %%
### EXERCISE: find some data in lat, lon (e.g. at http://data.gov), 
### import it into a dataframe or data source, and add it on the map above.
