# %% [markdown]
# ## <div style="float:left">
#     <a href="http://bokeh.pydata.org/">
#     <img src="http://bokeh.pydata.org/_static/bokeh-transparent.png" style="display:inline-block; width:90px"></a>
#     <h1  style="display:inline-block">Bokeh tutorial - Basic Exercises</h1>
# </div>

# %% [markdown]
# This is the IPython Notebook version of the Bokeh Tutorial available at http://bokeh.pydata.org/tutorial/basic.html

# %%
import bokeh.bokeh_magic
# %bokeh --notebook
# Out:
# Bokeh magic loaded.
#
#         <style>
#             /* BEGIN /Users/Christine/.virtualenvs/python_science/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
#                 /*!
#                  * Bootstrap v2.0.4
#                  *
#                  * Copyright 2012 Twitter, Inc
#                  * Licensed under the Apache License v2.0
#                  * http://www.apache.org/licenses/LICENSE-2.0
#                  *
#                  * Designed and built with all the love in the world @twitter by @mdo and @fat.
#                  */.bokeh article,.bokeh aside,.bokeh details,.bokeh figcaption,.bokeh figure,.bokeh footer,.bokeh header,.bokeh hgroup,.bokeh nav,.bokeh section{display:block}.bokeh audio,.bokeh canvas,.bokeh video{display:inline-block}.bokeh audio:not([controls]){display:none}.bokeh html{font-size:100%;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}.bokeh a:focus{outline:thin dotted #333;outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}.bokeh a:hover,.bokeh a:active{outline:0}.bokeh sub,.bokeh sup{position:relative;font-size:75%;line-height:0;vertical-align:baseline}.bokeh sup{top:-.5em}.bokeh sub{bottom:-.25em}.bokeh img{max-width:100%;vertical-align:middle;border:0;-ms-interpolation-mode:bicubic}.bokeh #map_canvas img{max-width:none}.bokeh button,.bokeh input,.bokeh select,.bokeh textarea{margin:0;font-size:100%;vertical-align:middle}.bokeh button,.bokeh input{line-height:normal}.bokeh button::-moz-focus-inner,.bokeh input::-moz-focus-inner{padding:0;border:0}.bokeh button,.bokeh input[type=button],.bokeh input[type=reset],.bokeh input[type=submit]{cursor:pointer;-webkit-appearance:button}.bokeh input[type=search]{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;-webkit-appearance:textfield}.bokeh input[type=search]::-webkit-search-decoration,.bokeh input[type=search]::-webkit-search-cancel-button{-webkit-appearance:none}.bokeh textarea{overflow:auto;vertical-align:top}.bokeh .clearfix{}.bokeh .clearfix:before,.bokeh .clearfix:after{display:table;content:""}.bokeh .clearfix:after{clear:both}.bokeh .hide-text{font:0/0 a;color:transparent;text-shadow:none;background-color:transparent;border:0}.bokeh .input-block-level{display:block;width:100%;min-height:28px;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box}.bokeh body{margin:0;font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:13px;line-height:18px;color:#333;background-color:#fff}.bokeh a{color:#08c;text-decoration:none}.bokeh a:hover{color:#005580;text-decoration:underline}.bokeh .row{margin-left:-20px}.bokeh .row:before,.bokeh .row:after{display:table;content:""}.bokeh .row:after{clear:both}.bokeh [class*=span]{float:left;margin-left:20px}.bokeh .container,.bokeh .navbar-fixed-top .container,.bokeh .navbar-fixed-bottom .container{width:940px}.bokeh .span12{width:940px}.bokeh .span11{width:860px}.bokeh .span10{width:780px}.bokeh .span9{width:700px}.bokeh .span8{width:620px}.bokeh .span7{width:540px}.bokeh .span6{width:460px}.bokeh .span5{width:380px}.bokeh .span4{width:300px}.bokeh .span3{width:220px}.bokeh .span2{width:140px}.bokeh .span1{width:60px}.bokeh .offset12{margin-left:980px}.bokeh .offset11{margin-left:900px}.bokeh .offset10{margin-left:820px}.bokeh .offset9{margin-left:740px}.bokeh .offset8{margin-left:660px}.bokeh .offset7{margin-left:580px}.bokeh .offset6{margin-left:500px}.bokeh .offset5{margin-left:420px}.bokeh .offset4{margin-left:340px}.bokeh .offset3{margin-left:260px}.bokeh .offset2{margin-left:180px}.bokeh .offset1{margin-left:100px}.bokeh .row-fluid{width:100%}.bokeh .row-fluid:before,.bokeh .row-fluid:after{display:table;content:""}.bokeh .row-fluid:after{clear:both}.bokeh .row-fluid [class*=span]{display:block;float:left;width:100%;min-height:28px;margin-left:2.127659574%;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box}.bokeh .row-fluid [class*=span]:first-child{margin-left:0}.bokeh .row-fluid .span12{width:99.99999998999999%}.bokeh .row-fluid .span11{width:91.489361693%}.bokeh .row-fluid .span10{width:82.97872339599999%}.bokeh .row-fluid .span9{width:74.468085099%}.bokeh .row-fluid .span8{width:65.95744680199999%}.bokeh .row-fluid .span7{width:57.446808505%}.bokeh .row-fluid .span6{width:48.93617020799999%}.bokeh .row-fluid .span5{width:40.425531911%}.bokeh .row-fluid .span4{width:31.914893614%}.bokeh .row-fluid .span3{width:23.404255317%}.bokeh .row-fluid .span2{width ...

# %% [markdown]
# ## 2. Scattering Points

# %%
from __future__ import division

import numpy as np
from six.moves import zip
from bokeh.plotting import *
from bokeh.objects import Range1d

# %%
# Recreate the Fermat spiral from the last exercise, with some different scalings
# and number of turnings
theta1 = np.linspace(0, 256*np.pi, 500)[1:]
f1 = theta1**(1/2)
x1 = 0.5*f1*np.cos(theta1)
y1 = 0.5*f1*np.sin(theta1)

theta2 = np.linspace(0, 96*np.pi, 500)[1:]
f2 = theta2**(1/2)
x2 = f2*f2*np.cos(theta2)
y2 = f2*f2*np.sin(theta2)

theta3 = np.linspace(0, 32*np.pi, 500)[1:]
f3 = 2*theta3**(1/2)
x3 = 2*f3*np.cos(theta3)
y3 = 2*f3*np.sin(theta3)

# %%
# Create a set of tools to use
TOOLS="pan,wheel_zoom,box_zoom,reset,previewsave"

# %%
# EXERCISE: create two Range1d objects to reuse in the plots. Use the [-20, 20]
# for the bounds.
xr = Range1d(start=-20, end=20)
yr = Range1d(start=-20, end=20)

# %%
# EXERCISE: Plot all the sets of points on different plots. Use the ranges above
# for x_range and y_range. Set different colors as well. Try setting line_color
# and fill_color instead of just color. You can also set alpha, line_alpha, and
# fill_alpha if you like. Set tools to TOOLS on the first renderer. Change
# the value of the 'marker' parameter, "circle", "square", "triangle", etc. One
# example is given

# %%
scatter(x1, y1, size=12, color="red", alpha=0.5,
        x_range=xr, y_range=yr, tools=TOOLS)
# %bokeh --show
# Out:
# Automatic show() is enabled.
# <script type="text/javascript">
#         $(function() {
#             var modelid = "b8d9918e-11e2-45b0-8ea2-141b1bfced97";
#             var modeltype = "Plot";
#             var elementid = "0e33286b-c805-433b-b2f3-dc446f5000e6";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"start": -20, "end": 20, "doc": null, "id": "4d39ed55-e7ee-42fe-afd5-2c52ae83f892"}, "type": "Range1d", "id": "4d39ed55-e7ee-42fe-afd5-2c52ae83f892"}, {"attributes": {"doc": null, "id": "52dcf0db-ba19-4690-9c9e-6458c6ad11ed"}, "type": "BasicTickFormatter", "id": "52dcf0db-ba19-4690-9c9e-6458c6ad11ed"}, {"attributes": {"data_source": {"type": "ColumnDataSource", "id": "a54e98bf-7c15-4e63-a102-247b7777bb9d"}, "server_data_source": null, "doc": null, "nonselection_glyphspec": {"line_color": {"value": "#1f77b4"}, "angle_units": "deg", "fill_color": {"value": "#1f77b4"}, "visible": null, "line_dash_offset": 0, "line_join": "miter", "size": {"units": "screen", "value": 12}, "line_alpha": {"units": "data", "value": 0.1}, "radius_units": "screen", "end_angle_units": "deg", "valign": null, "length_units": "screen", "start_angle_units": "deg", "line_cap": "butt", "line_dash": [], "line_width": {"units": "data", "field": "line_width"}, "type": "circle", "fill_alpha": {"units": "data", "value": 0.1}, "halign": null, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "margin": null}, "xdata_range": null, "ydata_range": null, "glyphspec": {"line_color": {"value": "red"}, "line_alpha": {"units": "data", "value": 0.5}, "fill_color": {"value": "red"}, "line_width": {"units": "data", "field": "line_width"}, "fill_alpha": {"units": "data", "value": 0.5}, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "type": "circle", "size": {"units": "screen", "value": 12}}, "id": "ecd41d21-585f-4ef6-a7b3-3423e67d86cf"}, "type": "Glyph", "id": "ecd41d21-585f-4ef6-a7b3-3423e67d86cf"}, {"attributes": {"plot": {"type": "Plot", "id": "b8d9918e-11e2-45b0-8ea2-141b1bfced97"}, "id": "d53f2ee6-1a62-473b-b81b-255176bfaadc", "doc": null}, "type": "ResetTool", "id": "d53f2ee6-1a62-473b-b81b-255176bfaadc"}, {"attributes": {"plot": {"type": "Plot", "id": "b8d9918e-11e2-45b0-8ea2-141b1bfced97"}, "dimensions": ["width", "height"], "doc": null, "id": "1b833dfe-ec14-4fad-afc6-5d954fc0647b"}, "type": "PanTool", "id": "1b833dfe-ec14-4fad-afc6-5d954fc0647b"}, {"attributes": {"plot": {"type": "Plot", "id": "b8d9918e-11e2-45b0-8ea2-141b1bfced97"}, "dimensions": ["width", "height"], "doc": null, "id": "d6bce0eb-ea69-483a-93ee-bad1d099377b"}, "type": "WheelZoomTool", "id": "d6bce0eb-ea69-483a-93ee-bad1d099377b"}, {"attributes": {"plot": {"type": "Plot", "id": "b8d9918e-11e2-45b0-8ea2-141b1bfced97"}, "doc": null, "bounds": "auto", "id": "c21489f5-d60e-4ec5-81c2-e8f443e889fa", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "47020036-09b1-4ac0-b51b-d68581d8f24a"}, "ticker": {"type": "BasicTicker", "id": "7132fb0d-7bb2-43d9-91a0-c4c3bcf80d13"}, "dimension": 1}, "type": "LinearAxis", "id": "c21489f5-d60e-4ec5-81c2-e8f443e889fa"}, {"attributes": {"plot": {"type": "Plot", "id": "b8d9918e-11e2-45b0-8ea2-141b1bfced97"}, "doc": null, "bounds": "auto", "id": "23d627c2-7266-443a-b9ff-98dfae1ab637", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "52dcf0db-ba19-4690-9c9e-6458c6ad11ed"}, "ticker": {"type": "BasicTicker", "id": "3593dae1-85ba-4734-9c4f-b6d04160cef3"}, "dimension": 0}, "type": "LinearAxis", "id": "23d627c2-7266-443a-b9ff-98dfae1ab637"}, {"attributes": {"doc": null, "id": "3593dae1-85ba-4734-9c4f-b6d04160cef3"}, "type": "BasicTicker", "id": "3593dae1-85
# %%
# %bokeh --show-off
# %bokeh --figure
# %bokeh --hold
# Out:
# Automatic show() is disabled.
# Automatic figure() is enabled.
# Automatic hold() is enabled.

# %%
# EXERCISE: Visualize all the sets of points on the same plot
scatter(x1, y1, size=12, color="red", alpha=0.5,
        x_range=xr, y_range=yr, tools=TOOLS)
scatter(x2, y2, size=12, color="blue", fill_alpha=0.5,
        x_range=xr, y_range=yr, marker="square")
scatter(x3, y3, size=12, fill_color="green", line_color="orange",
        x_range=xr, y_range=yr, marker="triangle")
# %bokeh --show
# Out:
# Automatic show() is enabled.
# <script type="text/javascript">
#         $(function() {
#             var modelid = "a0a7a424-faf6-4212-b3d6-fd5fd975a311";
#             var modeltype = "Plot";
#             var elementid = "005bf36f-4012-47e3-a40c-4923e7dd3fca";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"start": -20, "end": 20, "doc": null, "id": "4d39ed55-e7ee-42fe-afd5-2c52ae83f892"}, "type": "Range1d", "id": "4d39ed55-e7ee-42fe-afd5-2c52ae83f892"}, {"attributes": {"data_source": {"type": "ColumnDataSource", "id": "9e56fc9d-1a66-42c1-a397-7647d1476450"}, "server_data_source": null, "doc": null, "nonselection_glyphspec": {"line_color": {"value": "#1f77b4"}, "angle_units": "deg", "fill_color": {"value": "#1f77b4"}, "visible": null, "end_angle_units": "deg", "line_dash_offset": 0, "line_join": "miter", "size": {"units": "screen", "value": 12}, "line_alpha": {"units": "data", "value": 0.1}, "angle": {"units": "data", "field": "angle"}, "radius_units": "screen", "valign": null, "length_units": "screen", "start_angle_units": "deg", "line_cap": "butt", "line_dash": [], "line_width": {"units": "data", "field": "line_width"}, "type": "square", "fill_alpha": {"units": "data", "value": 0.1}, "halign": null, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "margin": null}, "xdata_range": null, "ydata_range": null, "glyphspec": {"line_color": {"value": "blue"}, "line_alpha": {"units": "data", "value": 1.0}, "angle": {"units": "data", "field": "angle"}, "fill_color": {"value": "blue"}, "line_width": {"units": "data", "field": "line_width"}, "fill_alpha": {"units": "data", "value": 0.5}, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "type": "square", "size": {"units": "screen", "value": 12}}, "id": "6563eacc-fe80-4ac6-8b44-67e284d8f867"}, "type": "Glyph", "id": "6563eacc-fe80-4ac6-8b44-67e284d8f867"}, {"attributes": {"data_source": {"type": "ColumnDataSource", "id": "6041048a-c30e-4218-a3c4-b23e067ad982"}, "server_data_source": null, "doc": null, "nonselection_glyphspec": {"line_color": {"value": "#1f77b4"}, "angle_units": "deg", "fill_color": {"value": "#1f77b4"}, "visible": null, "end_angle_units": "deg", "line_dash_offset": 0, "line_join": "miter", "size": {"units": "screen", "value": 12}, "line_alpha": {"units": "data", "value": 0.1}, "radius_units": "screen", "valign": null, "length_units": "screen", "start_angle_units": "deg", "line_cap": "butt", "line_dash": [], "line_width": {"units": "data", "field": "line_width"}, "type": "triangle", "fill_alpha": {"units": "data", "value": 0.1}, "halign": null, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "margin": null}, "xdata_range": null, "ydata_range": null, "glyphspec": {"line_color": {"value": "orange"}, "line_alpha": {"units": "data", "value": 1.0}, "fill_color": {"value": "green"}, "line_width": {"units": "data", "field": "line_width"}, "fill_alpha": {"units": "data", "value": 1.0}, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "type": "triangle", "size": {"units": "screen", "value": 12}}, "id": "7d0a2a26-33a2-4465-bf7e-aab5c27a793a"}, "type": "Glyph", "id": "7d0a2a26-33a2-4465-bf7e-aab5c27a793a"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "2cf3acd2-dc91-4878-89e5-544652ee7985"}, "type": "Range1d", "id": "2cf3acd2-dc91-4878-89e5-544652ee7985"}, {"attributes": {"outer_height": 600, "x_range": {"type": "Range1d", "id": "4d39ed55-e7ee-42fe-afd5-2c52ae83f892"}, "y_range": {"type": "Range1d", "id": "2cf3acd2-dc91-4878-89e5-544652ee7985"}, "outer_width": 600, "renderers": [{"type": "LinearAxis", "id": "5aed4c60-64f0-42c3-977d-4d24884b7312"}, {"type": "Grid", "id": "c003f70e-2b1e-4759-af07-223bbefb9dc2"}, {"type": "LinearAxis", "id": "95596c6c-2de3-4e6d-8157-7b9a6af85d96"}, {"type": "Grid", "id": "43e17cf0-36c8-46e5-95f3-1cdbc9748e24"}, {"type": "BoxSelection", "id": "1958bd26-72b2-42b5-98a3-c1e7981ed6d5"}, {"type": "Glyph", "id": "43138570-74f1-4a85-aded-f3a80de15518"}, {"type": "Glyph", "id": "6563eacc-fe80-4ac6-8b44-67e284d8f867"}, {"type": "Glyph", "id": "7d0a2a26-33a2-4465-bf7e-aab5c27a793a"}], "id": "a0a7a424-faf6-4212-b3d6-fd5fd975a311", "data_sources": [], "doc": null, "canvas_height": 600, "title": "Plot" ...

# %%
# %bokeh --hold-off
# %bokeh --show-off
# Out:
# Automatic hold() is disabled.
# Automatic show() is disabled.

# %%
# Lets plot 4000 circles, you can play around with this if you like
N = 4000

# %%
# Create a bunch of random points, radii and colors for plotting
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))
]

# %%
# EXERCISE: use the `circle` renderer to scatter all the circles. Set the
# 'fill_color' to the colors above, the 'line_color' to None, and the 'radius'
# to the radii. Also try setting the fill_alpha to something less than one.
# Use TOOLS from above to set a tools parameter.
circle(x, y, radius=radii,
       fill_color=colors, fill_alpha=0.6,
       line_color=None, Title="Colorful Scatter")
# %bokeh --show
# Out:
# Automatic show() is enabled.
# <script type="text/javascript">
#         $(function() {
#             var modelid = "f295f6db-0245-4248-8609-a61c3fe80e67";
#             var modeltype = "Plot";
#             var elementid = "f19e5b4e-9225-4316-a570-cf5ac65c4401";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"plot": null, "doc": null, "renderers": [{"type": "Glyph", "id": "14dd10aa-a983-4ea1-9e7e-1dfb2efc2117"}], "id": "3f4335ba-2108-4012-a059-59d8064b2052"}, "type": "BoxSelectTool", "id": "3f4335ba-2108-4012-a059-59d8064b2052"}, {"attributes": {"doc": null, "id": "9c40ec6d-ce3a-4b2f-b631-f8026a3d30de"}, "type": "BasicTicker", "id": "9c40ec6d-ce3a-4b2f-b631-f8026a3d30de"}, {"attributes": {"doc": null, "id": "f415db09-b28b-42cf-b797-c160f295bd09"}, "type": "BasicTickFormatter", "id": "f415db09-b28b-42cf-b797-c160f295bd09"}, {"attributes": {"plot": {"type": "Plot", "id": "f295f6db-0245-4248-8609-a61c3fe80e67"}, "doc": null, "axis": {"type": "LinearAxis", "id": "dc219c39-5969-4c9e-ac79-4f30860ea912"}, "id": "f99e2e79-c325-4977-b8d5-e842606f6f92", "dimension": 0}, "type": "Grid", "id": "f99e2e79-c325-4977-b8d5-e842606f6f92"}, {"attributes": {"plot": {"type": "Plot", "id": "f295f6db-0245-4248-8609-a61c3fe80e67"}, "doc": null, "axis": {"type": "LinearAxis", "id": "111064ee-68de-4244-ad17-466a28517c3d"}, "id": "91c924a2-c7e5-4c86-a077-848fe20f6799", "dimension": 1}, "type": "Grid", "id": "91c924a2-c7e5-4c86-a077-848fe20f6799"}, {"attributes": {"plot": {"type": "Plot", "id": "f295f6db-0245-4248-8609-a61c3fe80e67"}, "dimensions": ["width", "height"], "doc": null, "id": "3b65a97b-1658-4416-a1ca-9267b76a9783"}, "type": "PanTool", "id": "3b65a97b-1658-4416-a1ca-9267b76a9783"}, {"attributes": {"plot": {"type": "Plot", "id": "f295f6db-0245-4248-8609-a61c3fe80e67"}, "id": "586c28ce-e572-483c-b011-97d364ad45e0", "doc": null}, "type": "ResizeTool", "id": "586c28ce-e572-483c-b011-97d364ad45e0"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "a9c0fc96-0adb-4d4a-abb9-0df0b595d33d"}, "id": "5063da95-823f-40b9-a6a7-ac75676113cc"}, "type": "BoxSelection", "id": "5063da95-823f-40b9-a6a7-ac75676113cc"}, {"attributes": {"plot": {"type": "Plot", "id": "f295f6db-0245-4248-8609-a61c3fe80e67"}, "id": "94b76f1c-32f3-49d0-8a0f-773df2f75d80", "doc": null}, "type": "PreviewSaveTool", "id": "94b76f1c-32f3-49d0-8a0f-773df2f75d80"}, {"attributes": {"plot": {"type": "Plot", "id": "f295f6db-0245-4248-8609-a61c3fe80e67"}, "dimensions": ["width", "height"], "doc": null, "id": "d55ff69d-d3c3-4515-ae5a-2fffe6ea5f47"}, "type": "WheelZoomTool", "id": "d55ff69d-d3c3-4515-ae5a-2fffe6ea5f47"}, {"attributes": {"doc": null, "tool": {"type": "BoxSelectTool", "id": "3f4335ba-2108-4012-a059-59d8064b2052"}, "id": "85a422bb-cf86-46ec-a179-d021acd9379d"}, "type": "BoxSelection", "id": "85a422bb-cf86-46ec-a179-d021acd9379d"}, {"attributes": {"data_source": {"type": "ColumnDataSource", "id": "4b010eb9-b6c6-43e4-a902-5f27295ad360"}, "server_data_source": null, "doc": null, "nonselection_glyphspec": {"line_color": {"value": "#1f77b4"}, "angle_units": "deg", "fill_color": {"value": "#1f77b4"}, "visible": null, "line_dash_offset": 0, "line_join": "miter", "size": {"units": "screen", "default": 4, "field": null}, "line_alpha": {"units": "data", "value": 0.1}, "radius_units": "screen", "end_angle_units": "deg", "valign": null, "length_units": "screen", "start_angle_units": "deg", "line_cap": "butt", "line_dash": [], "line_width": {"units": "data", "field": "line_width"}, "type": "circle", "fill_alpha": {"units": "data", "value": 0.1}, "halign": null, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "margin": null}, "xdata_range": null, "ydata_range": null, "glyphspec": {"line_color": {"value": null}, "line_alpha": {"units": "data", "value": 1.0}, "fill_color": {"units": "data", "field": "fill_color"}, "line_width": {"units": "data", "field": "line_width"}, "fill_alpha": {"units": "data", "value": 0.6}, "radius": {"units": "data", "default": 4, "field": "radius"}, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "type": "circle"}, "id": "14dd10aa-a983-4ea1-9e7e-1dfb2efc2117"}, "type": "Glyph", "id": "14dd10aa-a983-4ea1-9e7e-1dfb2efc2117"}, {"attributes": {"plot": {"type": "Pl ...
