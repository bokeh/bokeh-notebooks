# %% [markdown]
# ## <div style="float:left">
#     <a href="http://bokeh.pydata.org/">
#     <img src="http://bokeh.pydata.org/_static/bokeh-transparent.png" style="display:inline-block; width:90px"></a>
#     <h1  style="display:inline-block">Bokeh tutorial - Basic Exercises</h1>
# </div>

# %% [markdown]
# This is the IPython Notebook version of the Bokeh Tutorial available at http://bokeh.pydata.org/tutorial/basic.html

# %% [markdown]
# ## 2. Scattering Points

# %%
from __future__ import division

import numpy as np
from six.moves import zip
from bokeh.plotting import *
from bokeh.objects import Range1d
output_notebook()
# Out:
#
#         <style>
#             /* BEGIN /Users/Christine/.virtualenvs/python_science/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
#                 /*!
#                  * Bootstrap v2.0.4
#                  *
#                  * Copyright 2012 Twitter, Inc
#                  * Licensed under the Apache License v2.0
#                  * http://www.apache.org/licenses/LICENSE-2.0
#                  *
#                  * Designed and built with all the love in the world @twitter by @mdo and @fat.
#                  */.bokeh article,.bokeh aside,.bokeh details,.bokeh figcaption,.bokeh figure,.bokeh footer,.bokeh header,.bokeh hgroup,.bokeh nav,.bokeh section{display:block}.bokeh audio,.bokeh canvas,.bokeh video{display:inline-block}.bokeh audio:not([controls]){display:none}.bokeh html{font-size:100%;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}.bokeh a:focus{outline:thin dotted #333;outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}.bokeh a:hover,.bokeh a:active{outline:0}.bokeh sub,.bokeh sup{position:relative;font-size:75%;line-height:0;vertical-align:baseline}.bokeh sup{top:-.5em}.bokeh sub{bottom:-.25em}.bokeh img{max-width:100%;vertical-align:middle;border:0;-ms-interpolation-mode:bicubic}.bokeh #map_canvas img{max-width:none}.bokeh button,.bokeh input,.bokeh select,.bokeh textarea{margin:0;font-size:100%;vertical-align:middle}.bokeh button,.bokeh input{line-height:normal}.bokeh button::-moz-focus-inner,.bokeh input::-moz-focus-inner{padding:0;border:0}.bokeh button,.bokeh input[type=button],.bokeh input[type=reset],.bokeh input[type=submit]{cursor:pointer;-webkit-appearance:button}.bokeh input[type=search]{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;-webkit-appearance:textfield}.bokeh input[type=search]::-webkit-search-decoration,.bokeh input[type=search]::-webkit-search-cancel-button{-webkit-appearance:none}.bokeh textarea{overflow:auto;vertical-align:top}.bokeh .clearfix{}.bokeh .clearfix:before,.bokeh .clearfix:after{display:table;content:""}.bokeh .clearfix:after{clear:both}.bokeh .hide-text{font:0/0 a;color:transparent;text-shadow:none;background-color:transparent;border:0}.bokeh .input-block-level{display:block;width:100%;min-height:28px;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box}.bokeh body{margin:0;font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:13px;line-height:18px;color:#333;background-color:#fff}.bokeh a{color:#08c;text-decoration:none}.bokeh a:hover{color:#005580;text-decoration:underline}.bokeh .row{margin-left:-20px}.bokeh .row:before,.bokeh .row:after{display:table;content:""}.bokeh .row:after{clear:both}.bokeh [class*=span]{float:left;margin-left:20px}.bokeh .container,.bokeh .navbar-fixed-top .container,.bokeh .navbar-fixed-bottom .container{width:940px}.bokeh .span12{width:940px}.bokeh .span11{width:860px}.bokeh .span10{width:780px}.bokeh .span9{width:700px}.bokeh .span8{width:620px}.bokeh .span7{width:540px}.bokeh .span6{width:460px}.bokeh .span5{width:380px}.bokeh .span4{width:300px}.bokeh .span3{width:220px}.bokeh .span2{width:140px}.bokeh .span1{width:60px}.bokeh .offset12{margin-left:980px}.bokeh .offset11{margin-left:900px}.bokeh .offset10{margin-left:820px}.bokeh .offset9{margin-left:740px}.bokeh .offset8{margin-left:660px}.bokeh .offset7{margin-left:580px}.bokeh .offset6{margin-left:500px}.bokeh .offset5{margin-left:420px}.bokeh .offset4{margin-left:340px}.bokeh .offset3{margin-left:260px}.bokeh .offset2{margin-left:180px}.bokeh .offset1{margin-left:100px}.bokeh .row-fluid{width:100%}.bokeh .row-fluid:before,.bokeh .row-fluid:after{display:table;content:""}.bokeh .row-fluid:after{clear:both}.bokeh .row-fluid [class*=span]{display:block;float:left;width:100%;min-height:28px;margin-left:2.127659574%;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;box-sizing:border-box}.bokeh .row-fluid [class*=span]:first-child{margin-left:0}.bokeh .row-fluid .span12{width:99.99999998999999%}.bokeh .row-fluid .span11{width:91.489361693%}.bokeh .row-fluid .span10{width:82.97872339599999%}.bokeh .row-fluid .span9{width:74.468085099%}.bokeh .row-fluid .span8{width:65.95744680199999%}.bokeh .row-fluid .span7{width:57.446808505%}.bokeh .row-fluid .span6{width:48.93617020799999%}.bokeh .row-fluid .span5{width:40.425531911%}.bokeh .row-fluid .span4{width:31.914893614%}.bokeh .row-fluid .span3{width:23.404255317%}.bokeh .row-fluid .span2{width ...

# %%
# Recreate the Fermat spiral from the last exercise, with some different scalings
# and number of turnings
theta1 = np.linspace(0, 256*np.pi, 500)[1:]
f1 = theta1**(1/2)
x1 = 0.5*f1*np.cos(theta1)
y1 = 0.5*f1*np.sin(theta1)

theta2 = np.linspace(0, 96*np.pi, 500)[1:]
f2 = theta2**(1/2)
x2 = f2*f2*np.cos(theta2)
y2 = f2*f2*np.sin(theta2)

theta3 = np.linspace(0, 32*np.pi, 500)[1:]
f3 = 2*theta3**(1/2)
x3 = 2*f3*np.cos(theta3)
y3 = 2*f3*np.sin(theta3)

# %%
# Create a set of tools to use
TOOLS="pan,wheel_zoom,box_zoom,reset,previewsave"

# %%
# EXERCISE: create two Range1d objects to reuse in the plots. Use the [-20, 20]
# for the bounds. Note: Range1d's are initialized like: Range1d(start=0, end=1)
xr = Range1d(start=-20, end=20)
yr = Range1d(start=-20, end=20)

# %%
# EXERCISE: Plot all the sets of points on different plots. Use the ranges above
# for x_range and y_range. Set different colors as well. Try setting line_color
# and fill_color instead of just color. You can also set alpha, line_alpha, and
# fill_alpha if you like. Set tools to TOOLS on the first renderer. Change
# the value of the 'marker' parameter, "circle", "square", "triangle", etc. One
# example is given

# %%
scatter(x1, y1, size=12, color="red", alpha=0.5,
        x_range=xr, y_range=yr, tools=TOOLS)
show()
# Out:
# <script type="text/javascript">
#         $(function() {
#             var modelid = "017f6a94-dce7-436f-adb2-a7c8e81add02";
#             var modeltype = "Plot";
#             var elementid = "e4ae226a-8d2b-4bdc-8ff8-548af90602fb";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"plot": {"type": "Plot", "id": "017f6a94-dce7-436f-adb2-a7c8e81add02"}, "doc": null, "bounds": "auto", "id": "f7139b9c-1094-492f-bb0f-373a008657df", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "dcd4c863-4a4f-4bd4-86ed-a469927e9574"}, "ticker": {"type": "BasicTicker", "id": "db19033a-2699-4691-ac55-a3d560f27967"}, "dimension": 1}, "type": "LinearAxis", "id": "f7139b9c-1094-492f-bb0f-373a008657df"}, {"attributes": {"plot": {"type": "Plot", "id": "017f6a94-dce7-436f-adb2-a7c8e81add02"}, "id": "4acc8efa-4b91-4ea3-ba9b-d368c01bb002", "doc": null}, "type": "BoxZoomTool", "id": "4acc8efa-4b91-4ea3-ba9b-d368c01bb002"}, {"attributes": {"doc": null, "id": "af3ced61-4e46-488c-baf8-0ce6043aef9b"}, "type": "BasicTickFormatter", "id": "af3ced61-4e46-488c-baf8-0ce6043aef9b"}, {"attributes": {"plot": {"type": "Plot", "id": "017f6a94-dce7-436f-adb2-a7c8e81add02"}, "doc": null, "axis": {"type": "LinearAxis", "id": "5ac48c7e-15d3-4c3f-b461-c471698ee993"}, "id": "68ca4733-05a4-4e35-b8bd-4d247402caa7", "dimension": 0}, "type": "Grid", "id": "68ca4733-05a4-4e35-b8bd-4d247402caa7"}, {"attributes": {"plot": {"type": "Plot", "id": "017f6a94-dce7-436f-adb2-a7c8e81add02"}, "id": "4d2a8daa-4994-41f8-ad96-3272fa06aa75", "doc": null}, "type": "PreviewSaveTool", "id": "4d2a8daa-4994-41f8-ad96-3272fa06aa75"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "0a7a2fc7-67ab-4ab8-a882-fa4656730a1e"}, "type": "Range1d", "id": "0a7a2fc7-67ab-4ab8-a882-fa4656730a1e"}, {"attributes": {"plot": {"type": "Plot", "id": "017f6a94-dce7-436f-adb2-a7c8e81add02"}, "dimensions": ["width", "height"], "doc": null, "id": "f76ae993-253e-400a-baeb-be80427c5501"}, "type": "PanTool", "id": "f76ae993-253e-400a-baeb-be80427c5501"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "4acc8efa-4b91-4ea3-ba9b-d368c01bb002"}, "id": "f676155d-9cf4-4b4e-94da-ff06e257bcee"}, "type": "BoxSelection", "id": "f676155d-9cf4-4b4e-94da-ff06e257bcee"}, {"attributes": {"start": -20, "end": 20, "doc": null, "id": "1145cd45-138e-4ed7-a6cb-35f2e23f8ac4"}, "type": "Range1d", "id": "1145cd45-138e-4ed7-a6cb-35f2e23f8ac4"}, {"attributes": {"outer_height": 600, "x_range": {"type": "Range1d", "id": "0a7a2fc7-67ab-4ab8-a882-fa4656730a1e"}, "y_range": {"type": "Range1d", "id": "1145cd45-138e-4ed7-a6cb-35f2e23f8ac4"}, "outer_width": 600, "renderers": [{"type": "LinearAxis", "id": "5ac48c7e-15d3-4c3f-b461-c471698ee993"}, {"type": "Grid", "id": "68ca4733-05a4-4e35-b8bd-4d247402caa7"}, {"type": "LinearAxis", "id": "f7139b9c-1094-492f-bb0f-373a008657df"}, {"type": "Grid", "id": "e42b195c-37ec-4b5f-819e-efe44d90d42c"}, {"type": "BoxSelection", "id": "f676155d-9cf4-4b4e-94da-ff06e257bcee"}, {"type": "Glyph", "id": "5efce800-261e-4a71-9fa0-2ce834b1363f"}], "id": "017f6a94-dce7-436f-adb2-a7c8e81add02", "data_sources": [], "doc": null, "canvas_height": 600, "title": "Plot", "tools": [{"type": "PanTool", "id": "f76ae993-253e-400a-baeb-be80427c5501"}, {"type": "WheelZoomTool", "id": "666a6454-0c21-4792-9de6-8815002fbe4e"}, {"type": "BoxZoomTool", "id": "4acc8efa-4b91-4ea3-ba9b-d368c01bb002"}, {"type": "ResetTool", "id": "4858130f-7ad2-4155-b4c9-a77849769d2a"}, {"type": "PreviewSaveTool", "id": "4d2a8daa-4994-41f8-ad96-3272fa06aa75"}], "canvas_width": 600}, "type": "Plot", "id": "017f6a94-dce7-436f-adb2-a7c8e81add02"}, {"attributes": {"data_source": {"type": "ColumnDataSource", "id": "b0e729a3-4299-40b1-baeb-958fbbbec1c8"}, "server_data_source": null, "doc": null, "nonselection_glyphspec": {"line_color": {"value": "#1f77b4"}, "angle_units": "deg", "fill_color": {"value": "#1f77b4"}, "visible": null, "line_dash_offset": 0, "line_join": "miter", "size": {"units": "screen", "value": 12}, "line_alpha": {"units": "data", "value": 0.1}, "radius_units": "screen", "end_angle_units": "deg", "valign": null, "length_units": "screen", "start_angle_units": "deg", "line_cap": "butt", "line_dash": [], "line_width": {"units": "data", "field": ...

# %%
scatter(x2, y2, size=12, color="blue", fill_alpha=0.5,
        x_range=xr, y_range=yr, marker="square")
show()
# Out:
# <script type="text/javascript">
#         $(function() {
#             var modelid = "2154102b-feb1-4e1e-b932-29b51c16b2e3";
#             var modeltype = "Plot";
#             var elementid = "0e0dbabb-82c3-4bad-abe7-6260f94cffae";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"plot": {"type": "Plot", "id": "2154102b-feb1-4e1e-b932-29b51c16b2e3"}, "dimensions": ["width", "height"], "doc": null, "id": "073fa8e2-1869-4a2c-99f8-7b7f67709fbe"}, "type": "PanTool", "id": "073fa8e2-1869-4a2c-99f8-7b7f67709fbe"}, {"attributes": {"column_names": ["_autoindex", "Series 1", "x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.3434556879238228, 1.1304449510246533, 1.760180230019235, 1.6013974785962082, 0.36062620880622365, -1.6899203688061855, -3.7494809964751945, -4.7987648834187375, -4.063691924715011, -1.4321968159895362, 2.374083341787467, 5.980830355610775, 7.857090593496979, 6.947362979656384, 3.1840087445808978, -2.350617218443932, -7.718711128756807, -10.805394493900339, -10.143471448770825, -5.565622591128945, 1.5939363224081244, 8.870224934212757, 13.51545368318466, 13.532728486585054, 8.507946549814205, -0.09893281491401099, -9.357657311163802, -15.863648095227571, -16.988252483446317, -11.924724849476775, -2.1187227474556645, 9.120463879726112, 17.733940466761453, 20.37850352935506, 15.714402271020315, 5.022723970552927, -8.116901360072289, -19.02071347383073, -23.570337493643567, -19.762329068749985, -8.556713421968135, 6.325269196714166, 19.631406642776685, 26.432119291587362, 23.943264014222617, 12.645300371961364, -3.74473482410466, -19.488899236189635, -28.836833544928474, -28.12412743439273, -17.195493896627603, 0.3957234169203097, 18.533589908290878, 30.665130609549376, 32.16695113346651, 22.098525778997598, 3.6801388454083233, -16.7251294379779, -31.808246847374775, -35.931968061267824, -27.2320300968785, -8.420530550188243, 14.043769185635258, 32.17074004836317, 39.280781594968076, 32.46253941343771, 13.743383904588049, -10.491294971458228, -31.672
# %%
# EXERCISE: Visualize all the sets of points on the same plot
figure()
hold()
scatter(x1, y1, size=12, color="red", alpha=0.5,
        x_range=xr, y_range=yr, tools=TOOLS)
scatter(x2, y2, size=12, color="blue", fill_alpha=0.5,
        x_range=xr, y_range=yr, marker="square")
scatter(x3, y3, size=12, fill_color="green", line_color="orange",
        x_range=xr, y_range=yr, marker="triangle")
show()
# Out:
# <script type="text/javascript">
#         $(function() {
#             var modelid = "eef333c5-5a65-47ba-8f9e-7b07ff63bc31";
#             var modeltype = "Plot";
#             var elementid = "aef55122-0c1c-480a-8747-25f12893a91d";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"column_names": ["_autoindex", "Series 1", "x", "y"], "doc": null, "selected": [], "discrete_ranges": {}, "cont_ranges": {}, "data": {"y": [0.35926681223105733, 0.9956076565413812, 1.767137830811523, 2.5904873014626295, 3.393984268912862, 4.112767243681258, 4.689081046926611, 5.073888149411536, 5.228730075655571, 5.127403174675577, 4.757221118910307, 4.119730966897256, 3.230807373352858, 2.120093734526425, 0.8297972578919507, -0.5871206346129396, -2.0692862949106665, -3.549689179196579, -4.958769566783514, -6.227681452276271, -7.291583408689071, -8.092806919254842, -8.583755214095193, -8.729395891751867, -8.509227135122293, -7.918619452633247, -6.969461646650546, -5.690069980642068, -4.124351971530027, -2.330249455440719, -0.3775181005320572, 1.655069074586984, 3.6829797365824306, 5.619505228921469, 7.379515510916531, 8.883223156481574, 10.059790679806403, 10.850619846538363, 11.212173145136067, 11.118195810887235, 10.561230996181425, 9.553349879585644, 8.126051491082864, 6.329322413331584, 4.22988279306021, 1.9086807029710413, -0.5422697140243498, -3.02358117693376, -5.432567429984391, -7.667530215502722, -9.632079055999807, -11.239299842605892, -12.415592060554768, -13.104006078693747, -13.266930882633021, -12.888008214996976, -11.973180285318113, -10.550813760223322, -8.670881176898797, -6.403220636498269, -3.8349339551171746, -1.0670207034719357, 1.7896208517363503, 4.618666446602592, 7.303130654487721, 9.730227708470796, 11.796125624895039, 13.410392871442005, 14.499947234219114, 15.012335083356593, 14.9181952221137, 14.2127939163699, 12.916555244625203, 11.074552059359782, 8.754965918068416, 6.046567538533199, 3.0553108470539563, -0.09982823746717927, -3.2916041370780533, -6.389654420083466, -9.265843611939998, -11.799578268811592, -13.882872352644632, -15.424949927894453, -16.356189138419687, -16.631236699658327, -16.23115478312514, -15.164500888258805, -13.467284536126417, -11.201790623217125, -8.45430615317456, -5.3318328780312605, -1.9579112135509016, 1.532281162032131, 4.997360984708797, 8.295482468588068, 11.290157866866778, 13.855916185126937, 15.88356510641219, 17.284835355549493, 17.996210160979512, 17.981774276466666, 17.234955958310476, 15.779079806044864, 13.666696672036688, 10.977706962287364, 7.816343530093318, 4.307127942152744, 0.5899571878981658, -3.1854849166181847, -6.8657678948144545, -10.299962102574701, -13.345838693253418, -15.875767001324936, -17.782064597675376, -18.98157573916891, -19.419283804276954, -19.070801417775854, -17.943626814496135, -16.077104779372497, -13.541083215966678, -10.433309889914065, -6.875665971071124, -3.0093815044601144, 1.0105791472572567, 5.021738335071077, 8.860682477919726, 12.36972906819914, 15.40341096333369, 17.834511045033786, 19.559396771088235, 20.502430987227086, 20.619271579926988, 19.898916713802752, 18.364402751678202, 16.072116477301908, 13.10973972072337, 9.592900619956522, 5.660659233877439, 1.4700038380139264, -2.8104240402417684, -7.007124715104253, -10.948781420931445, -14.47326129446586, -17.434289878110956, -19.707524185371014, -21.195772126738063, -21.833139325726375, -21.58792676637444, -20.46415262670589, -18.50162707067607, -15.774567459239451, -12.388801016702695, -8.477660017773784, -4.196728658430242, 0.282351298823489, 4.778769257083148, 9.10985213545658, 13.098492798339805, 16.58039821005364, 19.410860464202326, 21.470771505496746, 22.67163154539801, 22.959340746441608, 22.31661215642056, 20.763899185281815, 18.358790913564054, 15.193890776112054, 11.393256147085962, 7.107535527238987, 2.5079939678877845, -2.220336175498034, -6.886105023885072, -11.299395291272328, -15.279458584308445, -18.662122521402924, -21.306564961283932, -23.10117574316359, -23.968261995001342, -23.867398869714943, -22.797281706374214, -20.795995919139852, -17.939684962242477, -14.339661910376918, -10.138073875855055, -5.5022880498529725, -0.6182211527632524, 4.317121688782454, 9.103599003497829, 13.54605476550558, 17.46228 ...

# %%
# Lets plot 4000 circles, you can play around with this if you like
N = 4000

# %%
# Create a bunch of random points, radii and colors for plotting
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))
]

# %%
# EXERCISE: use the `circle` renderer to scatter all the circles. Set the
# 'fill_color' to the colors above, the 'line_color' to None, and the 'radius'
# to the radii. Also try setting the fill_alpha to something less than one.
# Use TOOLS from above to set a tools parameter.
figure()
hold()
circle(x, y, radius=radii,
       fill_color=colors, fill_alpha=0.6,
       line_color=None, Title="Colorful Scatter")
show()
# Out:
# <script type="text/javascript">
#         $(function() {
#             var modelid = "ba61bd8c-85e7-44d5-8fee-9a4e60334b7a";
#             var modeltype = "Plot";
#             var elementid = "798a29a3-40f1-4584-9ba0-83eee5534cc9";
#             console.log("  modeltype:", modeltype);
#             console.log("  modelid:", modelid);
#             console.log("  elementid:", elementid);
#             var all_models = [{"attributes": {"plot": {"type": "Plot", "id": "ba61bd8c-85e7-44d5-8fee-9a4e60334b7a"}, "id": "807478d4-6d84-418d-80a3-e7ce2053f636", "doc": null}, "type": "ResizeTool", "id": "807478d4-6d84-418d-80a3-e7ce2053f636"}, {"attributes": {"doc": null, "id": "6ff82bf3-f99b-4ca6-9713-45bc7d2f25b5"}, "type": "BasicTickFormatter", "id": "6ff82bf3-f99b-4ca6-9713-45bc7d2f25b5"}, {"attributes": {"plot": {"type": "Plot", "id": "ba61bd8c-85e7-44d5-8fee-9a4e60334b7a"}, "dimensions": ["width", "height"], "doc": null, "id": "88e06dd0-1c68-4f83-b811-3f3bd431d17f"}, "type": "PanTool", "id": "88e06dd0-1c68-4f83-b811-3f3bd431d17f"}, {"attributes": {"doc": null, "tool": {"type": "BoxZoomTool", "id": "c877696e-fea9-4677-89ed-9b02fbc90a3a"}, "id": "b4e1588e-4d10-4985-86f1-b0ce181475b2"}, "type": "BoxSelection", "id": "b4e1588e-4d10-4985-86f1-b0ce181475b2"}, {"attributes": {"doc": null, "tool": {"type": "BoxSelectTool", "id": "ec3b674a-74bb-49fe-bbb6-c90b216040ac"}, "id": "fca3cb5a-8256-4cc9-a6a6-87690d5db02a"}, "type": "BoxSelection", "id": "fca3cb5a-8256-4cc9-a6a6-87690d5db02a"}, {"attributes": {"doc": null, "id": "74c819de-5fc3-4db0-80e5-46725205ca95"}, "type": "BasicTicker", "id": "74c819de-5fc3-4db0-80e5-46725205ca95"}, {"attributes": {"data_source": {"type": "ColumnDataSource", "id": "37855626-43c7-4b4c-940d-6c01dd7a9403"}, "server_data_source": null, "doc": null, "nonselection_glyphspec": {"line_color": {"value": "#1f77b4"}, "angle_units": "deg", "fill_color": {"value": "#1f77b4"}, "visible": null, "line_dash_offset": 0, "line_join": "miter", "size": {"units": "screen", "default": 4, "field": null}, "line_alpha": {"units": "data", "value": 0.1}, "radius_units": "screen", "end_angle_units": "deg", "valign": null, "length_units": "screen", "start_angle_units": "deg", "line_cap": "butt", "line_dash": [], "line_width": {"units": "data", "field": "line_width"}, "type": "circle", "fill_alpha": {"units": "data", "value": 0.1}, "halign": null, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "margin": null}, "xdata_range": null, "ydata_range": null, "glyphspec": {"line_color": {"value": null}, "line_alpha": {"units": "data", "value": 1.0}, "fill_color": {"units": "data", "field": "fill_color"}, "line_width": {"units": "data", "field": "line_width"}, "fill_alpha": {"units": "data", "value": 0.6}, "radius": {"units": "data", "default": 4, "field": "radius"}, "y": {"units": "data", "field": "y"}, "x": {"units": "data", "field": "x"}, "type": "circle"}, "id": "7bf172b4-57dc-4fcb-a1b5-5c975935eada"}, "type": "Glyph", "id": "7bf172b4-57dc-4fcb-a1b5-5c975935eada"}, {"attributes": {"plot": {"type": "Plot", "id": "ba61bd8c-85e7-44d5-8fee-9a4e60334b7a"}, "doc": null, "axis": {"type": "LinearAxis", "id": "5f509108-369c-49f5-b005-231eb89e1149"}, "id": "717c02e4-4cae-45bd-8069-9e5f1cd04f0f", "dimension": 0}, "type": "Grid", "id": "717c02e4-4cae-45bd-8069-9e5f1cd04f0f"}, {"attributes": {"sources": [{"source": {"type": "ColumnDataSource", "id": "37855626-43c7-4b4c-940d-6c01dd7a9403"}, "columns": ["y"]}], "id": "ba73f858-1c0f-439a-b7d9-570e84ca305a", "doc": null}, "type": "DataRange1d", "id": "ba73f858-1c0f-439a-b7d9-570e84ca305a"}, {"attributes": {"plot": {"type": "Plot", "id": "ba61bd8c-85e7-44d5-8fee-9a4e60334b7a"}, "doc": null, "bounds": "auto", "id": "5f509108-369c-49f5-b005-231eb89e1149", "location": "min", "formatter": {"type": "BasicTickFormatter", "id": "f75893d2-6210-4946-bc8d-c013e0c7642f"}, "ticker": {"type": "BasicTicker", "id": "74c819de-5fc3-4db0-80e5-46725205ca95"}, "dimension": 0}, "type": "LinearAxis", "id": "5f509108-369c-49f5-b005-231eb89e1149"}, {"attributes": {"sources": [{"source": {"type": "ColumnDataSource", "id": "37855626-43c7-4b4c-940d-6c01dd7a9403"}, "columns": ["x"]}], "id": "44cec723-1be9-4ace-aaeb-5fe032fe214a", "doc": null}, "type": "DataRange1d", "id": "44cec723-1be9-4ace-aaeb-5fe032fe214a"}, {"attributes": {"column_names": ["fill_color", "radius", "x", "y"], "doc": null, "select ...
